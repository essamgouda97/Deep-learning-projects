# %% [markdown]
# # Task 3: Multi-class image classification
#
# STEPS:
# - Download the dataset using the script given in the notebook. Split them into 80% training and 20% validation sets and convert them to Keras dataset format using preprocessing methods. As seen in the tutorial notebook, visualize some sample images from every class.
#
# - Choose a pretrained convolutional neural network from the Keras package. Create new model by freezing the weights of the pretrained model and adding a dense classification layer appropriate for the number of classes that you have. Explain the overall architecture of your model and why it is chosen that way.
#
# - Train and evaluate the model using Keras. Choose an appropriate loss function. BinaryCrossentropy does not apply to this case anymore. Choose an appropriate metric as well.
#
# - Visualize the training and validation loss against the number of epochs. Explain what you see.
#
# - Visualize which classes are the most misclassified ones? Seaborn package has a nice tool to visualize the confusion matrix. How do you think we could improve the results? Some things to check:
#     - Does the data have any issues?
#     - Cleaning the data?
#     - Finding a better model?
#     - Does the model overfit the data? What is a remedy for overfitting? Dropout? Modifying hyperparameters? More augmentation?
#
# You should reach an accuracy of at least 80% on the validation split.
#
# CHECK MARKING SCHEME FOR MORE INFO

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers 
from keras.wrappers.scikit_learn import KerasClassifier
from keras.applications import VGG19, ResNet50, ResNet152V2 #For Transfer Learning

from __future__ import absolute_import, division, print_function, unicode_literals


from tensorboard.plugins.hparams import api as hp


import matplotlib.pyplot as plt
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white bg for sns plots
sns.set(style="whitegrid", color_codes=True)

from sklearn.model_selection import GridSearchCV


import warnings; warnings.simplefilter('ignore')

import numpy as np

DATASET_PATH = "images/images"
SEED_NO = 123 #fixed seed number for reproducing the same results.
np.random.seed(SEED_NO)

# %% [markdown]
# ## Dataset
#
# Dataset was used using the "image.zip" file provided on eclass, then it was split into 80% testing and 20% validation.

# %%
image_size = (150, 150)
batch_size = 128

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=SEED_NO,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=SEED_NO,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 2084 files belonging to 21 classes.
# Using 1668 files for training.
# Found 2084 files belonging to 21 classes.
# Using 416 files for validation.

# %% [markdown]
# Samples from the dataset

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# Multiple augmentation methods were used such as flipping, rotating and zooming. More could be added if needed to the pipeline.

# %%
data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal", seed=SEED_NO),
        layers.experimental.preprocessing.RandomRotation(0.1, seed=SEED_NO),
        #tf.keras.layers.experimental.preprocessing.RandomContrast(0.1, seed=SEED_NO),
        tf.keras.layers.experimental.preprocessing.RandomZoom(0.2, 0.1, seed=SEED_NO)
        
    ]
)

# %% [markdown]
# Visualizing samples from the augmented data.

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# Initalizing tensorboard

# %%
# %load_ext tensorboard

# %%
# !rm -rf ./logs/hparam_tuning

# %% [markdown]
# ## Base model without tuning
# Base model used ResNet50 without any hyperparameter tuning to check the results.

# %%
input_shape = (150, 150, 3)
num_classes = 21


def create_base_model():
    
    base_model = ResNet50(include_top = False, weights = 'imagenet', input_shape = input_shape, pooling='avg')

    # Freeze the base_model
    base_model.trainable = False

    # Create new model on top
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)  # Apply random data augmentation


    x = base_model(x, training=False)
    x = keras.layers.Flatten()(x)
    outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
    model = keras.Model(inputs, outputs)

    optimizer = keras.optimizers.Adam(lr=3e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

    model.compile(
                  loss='sparse_categorical_crossentropy', 
                  metrics=['acc'],
                  optimizer=optimizer
             )
    
    return model

#model.summary()

# %%
model = create_base_model()
history = model.fit(train_ds,epochs=50,validation_data=val_ds)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 9s 369ms/step - loss: 3.8305 - acc: 0.0524 - val_loss: 3.0069 - val_acc: 0.1418
# Epoch 2/50
# 14/14 [==============================] - 5s 285ms/step - loss: 2.8583 - acc: 0.1773 - val_loss: 2.3889 - val_acc: 0.3053
# Epoch 3/50
# 14/14 [==============================] - 5s 286ms/step - loss: 2.2951 - acc: 0.3086 - val_loss: 1.9974 - val_acc: 0.3846
# Epoch 4/50
# 14/14 [==============================] - 5s 298ms/step - loss: 1.9590 - acc: 0.4008 - val_loss: 1.7670 - val_acc: 0.4591
# Epoch 5/50
# 14/14 [==============================] - 5s 289ms/step - loss: 1.7454 - acc: 0.4436 - val_loss: 1.6209 - val_acc: 0.5000
# Epoch 6/50
# 14/14 [==============================] - 5s 282ms/step - loss: 1.5948 - acc: 0.5212 - val_loss: 1.4837 - val_acc: 0.5361
# Epoch 7/50
# 14/14 [==============================] - 5s 279ms/step - loss: 1.4385 - acc: 0.5452 - val_loss: 1.4033 - val_acc: 0.5505
# Epoch 8/50
# 14/14 [==============================] - 5s 279ms/step - loss: 1.3881 - acc: 0.5585 - val_loss: 1.3537 - val_acc: 0.5721
# Epoch 9/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.2769 - acc: 0.6182 - val_loss: 1.3112 - val_acc: 0.5817
# Epoch 10/50
# 14/14 [==============================] - 5s 277ms/step - loss: 1.2602 - acc: 0.6044 - val_loss: 1.2849 - val_acc: 0.6010
# Epoch 11/50
# 14/14 [==============================] - 5s 319ms/step - loss: 1.1820 - acc: 0.6188 - val_loss: 1.2421 - val_acc: 0.5986
# Epoch 12/50
# 14/14 [==============================] - 5s 285ms/step - loss: 1.1275 - acc: 0.6531 - val_loss: 1.2146 - val_acc: 0.6082
# Epoch 13/50
# 14/14 [==============================] - 5s 294ms/step - loss: 1.0746 - acc: 0.6610 - val_loss: 1.1936 - val_acc: 0.6250
# Epoch 14/50
# 14/14 [==============================] - 5s 266ms/step - loss: 1.0174 - acc: 0.6866 - val_loss: 1.1657 - val_acc: 0.6346
# Epoch 15/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.0034 - acc: 0.6802 - val_loss: 1.1498 - val_acc: 0.6250
# Epoch 16/50
# 14/14 [==============================] - 5s 279ms/step - loss: 0.9944 - acc: 0.6806 - val_loss: 1.1455 - val_acc: 0.6370
# Epoch 17/50
# 14/14 [==============================] - 5s 289ms/step - loss: 0.9442 - acc: 0.7139 - val_loss: 1.1378 - val_acc: 0.6514
# Epoch 18/50
# 14/14 [==============================] - 5s 270ms/step - loss: 0.8989 - acc: 0.7281 - val_loss: 1.1237 - val_acc: 0.6370
# Epoch 19/50
# 14/14 [==============================] - 5s 282ms/step - loss: 0.9005 - acc: 0.7129 - val_loss: 1.1122 - val_acc: 0.6442
# Epoch 20/50
# 14/14 [==============================] - 5s 278ms/step - loss: 0.8940 - acc: 0.7141 - val_loss: 1.0966 - val_acc: 0.6418
# Epoch 21/50
# 14/14 [==============================] - 5s 303ms/step - loss: 0.8766 - acc: 0.7224 - val_loss: 1.0824 - val_acc: 0.6490
# Epoch 22/50
# 14/14 [==============================] - 5s 280ms/step - loss: 0.8269 - acc: 0.7586 - val_loss: 1.0872 - val_acc: 0.6562
# Epoch 23/50
# 14/14 [==============================] - 5s 304ms/step - loss: 0.8112 - acc: 0.7426 - val_loss: 1.0808 - val_acc: 0.6466
# Epoch 24/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.8302 - acc: 0.7421 - val_loss: 1.0777 - val_acc: 0.6538
# Epoch 25/50
# 14/14 [==============================] - 5s 280ms/step - loss: 0.7925 - acc: 0.7558 - val_loss: 1.0665 - val_acc: 0.6731
# Epoch 26/50
# 14/14 [==============================] - 5s 284ms/step - loss: 0.7248 - acc: 0.7720 - val_loss: 1.0828 - val_acc: 0.6562
# Epoch 27/50
# 14/14 [==============================] - 5s 290ms/step - loss: 0.7386 - acc: 0.7834 - val_loss: 1.0744 - val_acc: 0.6514
# Epoch 28/50
# 14/14 [==============================] - 5s 287ms/step - loss: 0.7402 - acc: 0.7678 - val_loss: 1.0432 - val_acc: 0.6611
# Epoch 29/50
# 14/14 [==============================] - 5s 291ms/step - loss: 0.6845 - acc: 0.8037 - val_loss: 1.0565 - val_acc: 0.6538
# Epoch 30/50
# 14/14 [==============================] - 5s 293ms/step - loss: 0.7123 - acc: 0.7864 - val_loss: 1.0534 - val_acc: 0.6755
# Epoch 31/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.6628 - acc: 0.7964 - val_loss: 1.0498 - val_acc: 0.6659
# Epoch 32/50
# 14/14 [==============================] - 5s 285ms/step - loss: 0.6874 - acc: 0.7827 - val_loss: 1.0390 - val_acc: 0.6683
# Epoch 33/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.6573 - acc: 0.8120 - val_loss: 1.0321 - val_acc: 0.6707
# Epoch 34/50
# 14/14 [==============================] - 5s 284ms/step - loss: 0.6640 - acc: 0.7988 - val_loss: 1.0489 - val_acc: 0.6707
# Epoch 35/50
# 14/14 [==============================] - 5s 283ms/step - loss: 0.6404 - acc: 0.7934 - val_loss: 1.0300 - val_acc: 0.6707
# Epoch 36/50
# 14/14 [==============================] - 5s 301ms/step - loss: 0.6604 - acc: 0.8015 - val_loss: 1.0336 - val_acc: 0.6827
# Epoch 37/50
# 14/14 [==============================] - 5s 290ms/step - loss: 0.6039 - acc: 0.8203 - val_loss: 1.0531 - val_acc: 0.6683
# Epoch 38/50
# 14/14 [==============================] - 5s 292ms/step - loss: 0.5771 - acc: 0.8189 - val_loss: 1.0369 - val_acc: 0.6707
# Epoch 39/50
# 14/14 [==============================] - 5s 279ms/step - loss: 0.6035 - acc: 0.8213 - val_loss: 1.0404 - val_acc: 0.6779
# Epoch 40/50
# 14/14 [==============================] - 5s 303ms/step - loss: 0.5723 - acc: 0.8376 - val_loss: 1.0170 - val_acc: 0.6755
# Epoch 41/50
# 14/14 [==============================] - 5s 291ms/step - loss: 0.5718 - acc: 0.8267 - val_loss: 1.0159 - val_acc: 0.6707
# Epoch 42/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.5465 - acc: 0.8504 - val_loss: 1.0180 - val_acc: 0.6683
# Epoch 43/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.5586 - acc: 0.8247 - val_loss: 1.0105 - val_acc: 0.6731
# Epoch 44/50
# 14/14 [==============================] - 5s 287ms/step - loss: 0.5497 - acc: 0.8401 - val_loss: 1.0227 - val_acc: 0.6683
# Epoch 45/50
# 14/14 [==============================] - 5s 291ms/step - loss: 0.5562 - acc: 0.8451 - val_loss: 1.0269 - val_acc: 0.6803
# Epoch 46/50
# 14/14 [==============================] - 5s 284ms/step - loss: 0.5610 - acc: 0.8303 - val_loss: 1.0125 - val_acc: 0.6707
# Epoch 47/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.5299 - acc: 0.8367 - val_loss: 1.0214 - val_acc: 0.6731
# Epoch 48/50
# 14/14 [==============================] - 5s 287ms/step - loss: 0.5247 - acc: 0.8458 - val_loss: 1.0131 - val_acc: 0.6827
# Epoch 49/50
# 14/14 [==============================] - 5s 292ms/step - loss: 0.5431 - acc: 0.8309 - val_loss: 1.0021 - val_acc: 0.6851
# Epoch 50/50
# 14/14 [==============================] - 5s 272ms/step - loss: 0.5448 - acc: 0.8435 - val_loss: 1.0027 - val_acc: 0.6947

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()

# %%
# Evaluating model on validation data
evaluate = model.evaluate(val_ds)
print(evaluate)
# Out:
# 4/4 [==============================] - 1s 137ms/step - loss: 1.0027 - acc: 0.6947
# [1.0027267932891846, 0.6947115659713745]

# %%
from sklearn.metrics import confusion_matrix


y_pred = model.predict(val_ds)
y_pred = np.argmax(y_pred,axis=1)
y_true = tf.concat([y for x, y in val_ds], axis=0)
con_mat = confusion_matrix(y_true, y_pred)

# %%
figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# ## Hyperparameter tuning
# The base model showed low accuracy and that could occur due to the lack of extra dense layers and no hyperparamter tuning was tested during the constructing of the base model. In this section we add more hidden dense layers for the transfer learning layers and apply hyperparameter tuning to reach better validation accuracy.
#
# NOTE: THIS PART TAKES LONG TIME TO RUN AND TEST (this can be ignored as the final results and model will be trained on the chosen params later)

# %%
HP_NUM_UNITS1 = hp.HParam('num_units 1', hp.Discrete([1024])) 
HP_NUM_UNITS2 = hp.HParam('num_units 2', hp.Discrete([512]))
HP_NUM_UNITS3 = hp.HParam('num_units 3', hp.Discrete([256]))
HP_NUM_UNITS4 = hp.HParam('num_units 4', hp.Discrete([128]))
HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.2, 0.5))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd','RMSprop']))
HP_L2 = hp.HParam('l2 regularizer', hp.RealInterval(.001,.01))
HP_ACTIVATION = hp.HParam('activation func', hp.Discrete(['relu', 'gelu','selu']))
METRIC_ACCURACY = 'accuracy'


with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
  hp.hparams_config(
    hparams=[HP_NUM_UNITS1,HP_NUM_UNITS2, HP_NUM_UNITS3, HP_NUM_UNITS4, HP_DROPOUT,HP_L2 ,HP_OPTIMIZER, HP_ACTIVATION],
    metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
  )

# %%
input_shape = (150, 150, 3)
num_classes = 21


def create_model(hparams):
    
    base_model = ResNet50(include_top = False, weights = 'imagenet', input_shape = input_shape, pooling='avg')



    # Freeze the base_model
    base_model.trainable = False

    # Create new model on top
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)  # Apply random data augmentation


    x = base_model(x, training=False)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(hparams[HP_NUM_UNITS1], activation=hparams[HP_ACTIVATION], input_dim=512)(x)
    x = keras.layers.Dropout(hparams[HP_DROPOUT])(x)  # Regularize with dropout
    x = keras.layers.Dense(hparams[HP_NUM_UNITS2], activation=hparams[HP_ACTIVATION], kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_L2]))(x)
    x = keras.layers.Dropout(hparams[HP_DROPOUT])(x)  # Regularize with dropout
    x = keras.layers.Dense(hparams[HP_NUM_UNITS3], activation=hparams[HP_ACTIVATION], kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_L2]))(x)
    x = keras.layers.Dropout(hparams[HP_DROPOUT])(x)  # Regularize with dropout
    x = keras.layers.Dense(hparams[HP_NUM_UNITS4], activation=hparams[HP_ACTIVATION])(x)
    x = keras.layers.Dropout(hparams[HP_DROPOUT])(x)  # Regularize with dropout
    outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
    model = keras.Model(inputs, outputs)
    
    model.compile(
                  loss='sparse_categorical_crossentropy', 
                  metrics=['acc'],
                  optimizer=hparams[HP_OPTIMIZER]
             )
    
    model.fit(train_ds, validation_data=val_ds, epochs=50)
    _, accuracy = model.evaluate(val_ds)
    return accuracy

# %%
def run(run_dir, hparams):
  with tf.summary.create_file_writer(run_dir).as_default():
    hp.hparams(hparams)  # record the values used in this trial
    accuracy = create_model(hparams)
    tf.summary.scalar(METRIC_ACCURACY, accuracy, step=1)

# %%
session_num = 0
for num_units1 in HP_NUM_UNITS1.domain.values:
  for num_units2 in HP_NUM_UNITS2.domain.values:
      for num_units3 in HP_NUM_UNITS3.domain.values:
          for num_units4 in HP_NUM_UNITS4.domain.values:
            for dropout_rate in (HP_DROPOUT.domain.min_value, HP_DROPOUT.domain.max_value):
              for l2 in (HP_L2.domain.min_value, HP_L2.domain.max_value):
                for optimizer in HP_OPTIMIZER.domain.values:
                    for act in HP_ACTIVATION.domain.values:
                    

                      hparams = {
                          HP_NUM_UNITS1: num_units1,
                          HP_NUM_UNITS2: num_units2,
                          HP_NUM_UNITS3: num_units3,
                          HP_NUM_UNITS4: num_units4,
                          HP_DROPOUT: dropout_rate,
                          HP_L2: l2,
                          HP_OPTIMIZER: optimizer,
                          HP_ACTIVATION: act

                      }
                      run_name = "run-%d" % session_num
                      print('--- Starting trial: %s' % run_name)
                      print({h.name: hparams[h] for h in hparams})
                      run('logs/hparam_tuning/' + run_name, hparams)
                      session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units 1': 1024, 'num_units 2': 512, 'num_units 3': 256, 'num_units 4': 128, 'dropout': 0.2, 'l2 regularizer': 0.001, 'optimizer': 'RMSprop', 'activation func': 'gelu'}
# Epoch 1/50
# 14/14 [==============================] - 7s 327ms/step - loss: 4.7374 - acc: 0.0857 - val_loss: 3.6610 - val_acc: 0.2043
# Epoch 2/50
# 14/14 [==============================] - 5s 280ms/step - loss: 3.4585 - acc: 0.2679 - val_loss: 3.5254 - val_acc: 0.2212
# Epoch 3/50
# 14/14 [==============================] - 5s 278ms/step - loss: 3.0155 - acc: 0.3520 - val_loss: 3.0200 - val_acc: 0.3269
# Epoch 4/50
# 14/14 [==============================] - 5s 278ms/step - loss: 2.6934 - acc: 0.4205 - val_loss: 2.3356 - val_acc: 0.4736
# Epoch 5/50
# 14/14 [==============================] - 5s 278ms/step - loss: 2.3519 - acc: 0.4766 - val_loss: 2.1943 - val_acc: 0.5096
# Epoch 6/50
# 14/14 [==============================] - 5s 282ms/step - loss: 2.1633 - acc: 0.5135 - val_loss: 2.6386 - val_acc: 0.4639
# Epoch 7/50
# 14/14 [==============================] - 5s 279ms/step - loss: 2.2195 - acc: 0.5114 - val_loss: 2.2309 - val_acc: 0.5120
# Epoch 8/50
# 14/14 [==============================] - 5s 280ms/step - loss: 1.9215 - acc: 0.5808 - val_loss: 2.0483 - val_acc: 0.5649
# Epoch 9/50
# 14/14 [==============================] - 5s 282ms/step - loss: 1.8246 - acc: 0.6190 - val_loss: 1.9149 - val_acc: 0.6082
# Epoch 10/50
# 14/14 [==============================] - 5s 297ms/step - loss: 1.7513 - acc: 0.6238 - val_loss: 2.2915 - val_acc: 0.5433
# Epoch 11/50
# 14/14 [==============================] - 5s 285ms/step - loss: 1.6662 - acc: 0.6450 - val_loss: 1.7540 - val_acc: 0.6466
# Epoch 12/50
# 14/14 [==============================] - 5s 286ms/step - loss: 1.5347 - acc: 0.6880 - val_loss: 2.2275 - val_acc: 0.5817
# Epoch 13/50
# 14/14 [==============================] - 5s 288ms/step - loss: 1.4560 - acc: 0.7004 - val_loss: 2.3141 - val_acc: 0.5264
# Epoch 14/50
# 14/14 [==============================] - 5s 289ms/step - loss: 1.5864 - acc: 0.6717 - val_loss: 2.1769 - val_acc: 0.6010
# Epoch 15/50
# 14/14 [==============================] - 5s 290ms/step - loss: 1.5466 - acc: 0.6610 - val_loss: 5.5996 - val_acc: 0.3918
# Epoch 16/50
# 14/14 [==============================] - 5s 290ms/step - loss: 2.4951 - acc: 0.6206 - val_loss: 1.7994 - val_acc: 0.6178
# Epoch 17/50
# 14/14 [==============================] - 5s 300ms/step - loss: 1.1706 - acc: 0.7543 - val_loss: 2.1878 - val_acc: 0.5553
# Epoch 18/50
# 14/14 [==============================] - 5s 286ms/step - loss: 1.3746 - acc: 0.7196 - val_loss: 2.1876 - val_acc: 0.6106
# Epoch 19/50
# 14/14 [==============================] - 5s 285ms/step - loss: 1.3014 - acc: 0.7497 - val_loss: 2.9286 - val_acc: 0.5769
# Epoch 20/50
# 14/14 [==============================] - 5s 283ms/step - loss: 1.3000 - acc: 0.7576 - val_loss: 1.6604 - val_acc: 0.6659
# Epoch 21/50
# 14/14 [==============================] - 5s 282ms/step - loss: 1.1450 - acc: 0.7931 - val_loss: 1.7950 - val_acc: 0.6514
# Epoch 22/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.9789 - acc: 0.8204 - val_loss: 2.1465 - val_acc: 0.6178
# Epoch 23/50
# 14/14 [==============================] - 5s 286ms/step - loss: 1.0682 - acc: 0.7991 - val_loss: 1.6238 - val_acc: 0.6803
# Epoch 24/50
# 14/14 [==============================] - 5s 282ms/step - loss: 0.9399 - acc: 0.8247 - val_loss: 2.3496 - val_acc: 0.6010
# Epoch 25/50
# 14/14 [==============================] - 5s 283ms/step - loss: 1.2754 - acc: 0.7504 - val_loss: 1.5411 - val_acc: 0.7308
# Epoch 26/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.7747 - acc: 0.8677 - val_loss: 2.9640 - val_acc: 0.5673
# Epoch 27/50
# 14/14 [==============================] - 5s 277ms/step - loss: 1.1539 - acc: 0.7896 - val_loss: 1.9710 - val_acc: 0.6587
# Epoch 28/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.8441 - acc: 0.8519 - val_loss: 1.8547 - val_acc: 0.6562
# Epoch 29/50
# 14/14 [==============================] - 5s 287ms/step - loss: 0.9074 - acc: 0.8447 - val_loss: 1.4807 - val_acc: 0.7236
# Epoch 30/50
# 14/14 [==============================] - 5s 283ms/step - loss: 0.7624 - acc: 0.8682 - val_loss: 1.5747 - val_acc: 0.7067
# Epoch 31/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.6655 - acc: 0.8921 - val_loss: 2.3586 - val_acc: 0.6442
# Epoch 32/50
# 14/14 [==============================] - 5s 288ms/step - loss: 1.0511 - acc: 0.8058 - val_loss: 1.9063 - val_acc: 0.6082
# Epoch 33/50
# 14/14 [==============================] - 5s 285ms/step - loss: 0.6638 - acc: 0.8914 - val_loss: 1.6760 - val_acc: 0.6683
# Epoch 34/50
# 14/14 [==============================] - 5s 289ms/step - loss: 0.6050 - acc: 0.9135 - val_loss: 1.6422 - val_acc: 0.7043
# Epoch 35/50
# 14/14 [==============================] - 5s 297ms/step - loss: 0.6665 - acc: 0.8791 - val_loss: 2.1188 - val_acc: 0.6466
# Epoch 36/50
# 14/14 [==============================] - 5s 287ms/step - loss: 0.8832 - acc: 0.8272 - val_loss: 1.6566 - val_acc: 0.7091
# Epoch 37/50
# 14/14 [==============================] - 5s 288ms/step - loss: 0.5537 - acc: 0.9171 - val_loss: 1.8179 - val_acc: 0.6683
# Epoch 38/50
# 14/14 [==============================] - 5s 295ms/step - loss: 0.6702 - acc: 0.8944 - val_loss: 1.8565 - val_acc: 0.6827
# Epoch 39/50
# 14/14 [==============================] - 5s 286ms/step - loss: 0.7297 - acc: 0.8716 - val_loss: 1.8611 - val_acc: 0.6731
# Epoch 40/50
# 14/14 [==============================] - 5s 290ms/step - loss: 0.5908 - acc: 0.9034 - val_loss: 1.7293 - val_acc: 0.6803
# Epoch 41/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.6595 - acc: 0.8855 - val_loss: 1.7307 - val_acc: 0.7043
# Epoch 42/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.6332 - acc: 0.8866 - val_loss: 1.6586 - val_acc: 0.7019
# Epoch 43/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.6066 - acc: 0.8974 - val_loss: 2.1171 - val_acc: 0.6779
# Epoch 44/50
# 14/14 [==============================] - 5s 279ms/step - loss: 0.6467 - acc: 0.8874 - val_loss: 1.5986 - val_acc: 0.7067
# Epoch 45/50
# 14/14 [==============================] - 5s 280ms/step - loss: 0.4958 - acc: 0.9196 - val_loss: 2.1051 - val_acc: 0.6851
# Epoch 46/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.6277 - acc: 0.8777 - val_loss: 1.6508 - val_acc: 0.7212
# Epoch 47/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.5043 - acc: 0.9089 - val_loss: 1.8518 - val_acc: 0.7019
# Epoch 48/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.6317 - acc: 0.8818 - val_loss: 1.6241 - val_acc: 0.6971
# Epoch 49/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.4767 - acc: 0.9378 - val_loss: 1.5371 - val_acc: 0.7067
# Epoch 50/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.4022 - acc: 0.9498 - val_loss: 1.5375 - val_acc: 0.7139
# 4/4 [==============================] - 1s 137ms/step - loss: 1.5375 - acc: 0.7139
# --- Starting trial: run-1
# {'num_units 1': 1024, 'num_units 2': 512, 'num_units 3': 256, 'num_units 4': 128, 'dropout': 0.2, 'l2 regularizer': 0.001, 'optimizer': 'RMSprop', 'activation func': 'relu'}
# Epoch 1/50
# 14/14 [==============================] - 7s 311ms/step - loss: 4.6000 - acc: 0.0842 - val_loss: 3.9771 - val_acc: 0.1178
# Epoch 2/50
# 14/14 [==============================] - 5s 275ms/step - loss: 3.7017 - acc: 0.1764 - val_loss: 3.5850 - val_acc: 0.1731
# Epoch 3/50
# 14/14 [==============================] - 5s 278ms/step - loss: 3.2106 - acc: 0.2702 - val_loss: 2.9018 - val_acc: 0.3293
# Epoch 4/50
# 14/14 [==============================] - 5s 277ms/step - loss: 2.8263 - acc: 0.3660 - val_loss: 3.1297 - val_acc: 0.3101
# Epoch 5/50
# 14/14 [==============================] - 5s 281ms/step - loss: 2.6739 - acc: 0.3894 - val_loss: 2.4051 - val_acc: 0.4279
# Epoch 6/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.3156 - acc: 0.4698 - val_loss: 2.6152 - val_acc: 0.4087
# Epoch 7/50
# 14/14 [==============================] - 5s 289ms/step - loss: 2.2759 - acc: 0.4749 - val_loss: 2.1974 - val_acc: 0.5120
# Epoch 8/50
# 14/14 [==============================] - 5s 278ms/step - loss: 2.0022 - acc: 0.5354 - val_loss: 2.8323 - val_acc: 0.4423
# Epoch 9/50
# 14/14 [==============================] - 5s 319ms/step - loss: 2.0561 - acc: 0.5596 - val_loss: 3.0019 - val_acc: 0.4303
# Epoch 10/50
# 14/14 [==============================] - 5s 325ms/step - loss: 2.2188 - acc: 0.5319 - val_loss: 1.7428 - val_acc: 0.6226
# Epoch 11/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.6107 - acc: 0.6261 - val_loss: 1.9467 - val_acc: 0.5697
# Epoch 12/50
# 14/14 [==============================] - 5s 280ms/step - loss: 1.6099 - acc: 0.6439 - val_loss: 1.9223 - val_acc: 0.5625
# Epoch 13/50
# 14/14 [==============================] - 5s 299ms/step - loss: 1.5883 - acc: 0.6326 - val_loss: 1.7688 - val_acc: 0.6226
# Epoch 14/50
# 14/14 [==============================] - 5s 305ms/step - loss: 1.4827 - acc: 0.6744 - val_loss: 2.0977 - val_acc: 0.6274
# Epoch 15/50
# 14/14 [==============================] - 5s 282ms/step - loss: 1.5516 - acc: 0.6680 - val_loss: 2.0056 - val_acc: 0.5697
# Epoch 16/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.4535 - acc: 0.6747 - val_loss: 2.0326 - val_acc: 0.6202
# Epoch 17/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.3814 - acc: 0.6900 - val_loss: 2.0780 - val_acc: 0.6106
# Epoch 18/50
# 14/14 [==============================] - 5s 280ms/step - loss: 1.3231 - acc: 0.7121 - val_loss: 1.8809 - val_acc: 0.6202
# Epoch 19/50
# 14/14 [==============================] - 5s 279ms/step - loss: 1.2689 - acc: 0.7230 - val_loss: 1.9115 - val_acc: 0.6442
# Epoch 20/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.2227 - acc: 0.7576 - val_loss: 1.5055 - val_acc: 0.6971
# Epoch 21/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.0648 - acc: 0.7870 - val_loss: 1.7814 - val_acc: 0.6250
# Epoch 22/50
# 14/14 [==============================] - 5s 276ms/step - loss: 1.0617 - acc: 0.7693 - val_loss: 2.2561 - val_acc: 0.5793
# Epoch 23/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.1817 - acc: 0.7372 - val_loss: 2.4402 - val_acc: 0.5962
# Epoch 24/50
# 14/14 [==============================] - 5s 273ms/step - loss: 1.1367 - acc: 0.7807 - val_loss: 2.1307 - val_acc: 0.6490
# Epoch 25/50
# 14/14 [==============================] - 5s 277ms/step - loss: 1.0003 - acc: 0.8133 - val_loss: 2.6698 - val_acc: 0.5938
# Epoch 26/50
# 14/14 [==============================] - 5s 280ms/step - loss: 1.2561 - acc: 0.7632 - val_loss: 1.8453 - val_acc: 0.6611
# Epoch 27/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.9300 - acc: 0.8126 - val_loss: 1.6232 - val_acc: 0.6995
# Epoch 28/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.8258 - acc: 0.8345 - val_loss: 2.1053 - val_acc: 0.6322
# Epoch 29/50
# 14/14 [==============================] - 5s 278ms/step - loss: 0.9157 - acc: 0.8360 - val_loss: 2.1946 - val_acc: 0.6202
# Epoch 30/50
# 14/14 [==============================] - 5s 271ms/step - loss: 0.9275 - acc: 0.8170 - val_loss: 2.0862 - val_acc: 0.6034
# Epoch 31/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.9075 - acc: 0.8402 - val_loss: 2.0070 - val_acc: 0.6370
# Epoch 32/50
# 14/14 [==============================] - 5s 272ms/step - loss: 0.9368 - acc: 0.8056 - val_loss: 1.5514 - val_acc: 0.7019
# Epoch 33/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.7157 - acc: 0.8717 - val_loss: 1.6748 - val_acc: 0.6971
# Epoch 34/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.7371 - acc: 0.8464 - val_loss: 1.7687 - val_acc: 0.6611
# Epoch 35/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.8842 - acc: 0.8244 - val_loss: 1.4610 - val_acc: 0.6851
# Epoch 36/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.6508 - acc: 0.8952 - val_loss: 1.5832 - val_acc: 0.7188
# Epoch 37/50
# 14/14 [==============================] - 5s 283ms/step - loss: 0.6918 - acc: 0.8867 - val_loss: 1.8464 - val_acc: 0.6298
# Epoch 38/50
# 14/14 [==============================] - 5s 282ms/step - loss: 0.6560 - acc: 0.8764 - val_loss: 1.6685 - val_acc: 0.6803
# Epoch 39/50
# 14/14 [==============================] - 5s 286ms/step - loss: 0.5965 - acc: 0.8942 - val_loss: 1.6897 - val_acc: 0.6779
# Epoch 40/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.6530 - acc: 0.8892 - val_loss: 1.7328 - val_acc: 0.6947
# Epoch 41/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.6037 - acc: 0.8963 - val_loss: 1.4815 - val_acc: 0.7284
# Epoch 42/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.6358 - acc: 0.8915 - val_loss: 1.7673 - val_acc: 0.6538
# Epoch 43/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.5319 - acc: 0.9123 - val_loss: 1.6998 - val_acc: 0.6971
# Epoch 44/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.5250 - acc: 0.9236 - val_loss: 2.5543 - val_acc: 0.6034
# Epoch 45/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.7369 - acc: 0.8751 - val_loss: 1.4317 - val_acc: 0.7163
# Epoch 46/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.6028 - acc: 0.8863 - val_loss: 1.9661 - val_acc: 0.6755
# Epoch 47/50
# 14/14 [==============================] - 5s 280ms/step - loss: 0.6433 - acc: 0.8812 - val_loss: 1.6917 - val_acc: 0.6755
# Epoch 48/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.5207 - acc: 0.9125 - val_loss: 1.4039 - val_acc: 0.7332
# Epoch 49/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.4379 - acc: 0.9281 - val_loss: 1.8362 - val_acc: 0.6707
# Epoch 50/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.6210 - acc: 0.8990 - val_loss: 1.9735 - val_acc: 0.6947
# 4/4 [==============================] - 1s 136ms/step - loss: 1.9735 - acc: 0.6947
# --- Starting trial: run-2
# {'num_units 1': 1024, 'num_units 2': 512, 'num_units 3': 256, 'num_units 4': 128, 'dropout': 0.2, 'l2 regularizer': 0.001, 'optimizer': 'RMSprop', 'activation func': 'selu'}
# Epoch 1/50
# 14/14 [==============================] - 7s 316ms/step - loss: 10.9801 - acc: 0.0786 - val_loss: 7.3141 - val_acc: 0.1226
# Epoch 2/50
# 14/14 [==============================] - 5s 274ms/step - loss: 5.9904 - acc: 0.1873 - val_loss: 6.7608 - val_acc: 0.1538
# Epoch 3/50
# 14/14 [==============================] - 5s 280ms/step - loss: 5.5667 - acc: 0.2216 - val_loss: 6.3691 - val_acc: 0.2764
# Epoch 4/50
# 14/14 [==============================] - 5s 278ms/step - loss: 5.5179 - acc: 0.2683 - val_loss: 3.6456 - val_acc: 0.4399
# Epoch 5/50
# 14/14 [==============================] - 5s 277ms/step - loss: 3.4921 - acc: 0.3920 - val_loss: 4.5843 - val_acc: 0.2981
# Epoch 6/50
# 14/14 [==============================] - 5s 279ms/step - loss: 4.0052 - acc: 0.3700 - val_loss: 4.4717 - val_acc: 0.3438
# Epoch 7/50
# 14/14 [==============================] - 5s 278ms/step - loss: 3.8910 - acc: 0.4137 - val_loss: 3.2563 - val_acc: 0.5048
# Epoch 8/50
# 14/14 [==============================] - 5s 276ms/step - loss: 3.2547 - acc: 0.4433 - val_loss: 7.8541 - val_acc: 0.2188
# Epoch 9/50
# 14/14 [==============================] - 5s 277ms/step - loss: 4.2592 - acc: 0.3983 - val_loss: 3.6050 - val_acc: 0.4087
# Epoch 10/50
# 14/14 [==============================] - 5s 277ms/step - loss: 3.0346 - acc: 0.4979 - val_loss: 4.6113 - val_acc: 0.4327
# Epoch 11/50
# 14/14 [==============================] - 5s 275ms/step - loss: 3.6736 - acc: 0.4720 - val_loss: 4.2513 - val_acc: 0.4351
# Epoch 12/50
# 14/14 [==============================] - 5s 274ms/step - loss: 3.1222 - acc: 0.5126 - val_loss: 4.0575 - val_acc: 0.4351
# Epoch 13/50
# 14/14 [==============================] - 5s 272ms/step - loss: 3.4044 - acc: 0.4443 - val_loss: 3.2604 - val_acc: 0.5312
# Epoch 14/50
# 14/14 [==============================] - 5s 277ms/step - loss: 2.6382 - acc: 0.5668 - val_loss: 5.5076 - val_acc: 0.3702
# Epoch 15/50
# 14/14 [==============================] - 5s 278ms/step - loss: 3.0927 - acc: 0.5269 - val_loss: 4.5249 - val_acc: 0.4663
# Epoch 16/50
# 14/14 [==============================] - 5s 275ms/step - loss: 3.0581 - acc: 0.5229 - val_loss: 2.7506 - val_acc: 0.5481
# Epoch 17/50
# 14/14 [==============================] - 5s 280ms/step - loss: 2.2029 - acc: 0.6306 - val_loss: 3.1424 - val_acc: 0.5457
# Epoch 18/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.5909 - acc: 0.5756 - val_loss: 4.5877 - val_acc: 0.4303
# Epoch 19/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.9598 - acc: 0.5316 - val_loss: 2.4386 - val_acc: 0.5649
# Epoch 20/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.3267 - acc: 0.6039 - val_loss: 4.4063 - val_acc: 0.3486
# Epoch 21/50
# 14/14 [==============================] - 5s 276ms/step - loss: 2.8228 - acc: 0.5552 - val_loss: 3.0882 - val_acc: 0.4952
# Epoch 22/50
# 14/14 [==============================] - 5s 279ms/step - loss: 2.2710 - acc: 0.6141 - val_loss: 4.9392 - val_acc: 0.4712
# Epoch 23/50
# 14/14 [==============================] - 5s 278ms/step - loss: 2.6037 - acc: 0.6236 - val_loss: 2.4061 - val_acc: 0.6058
# Epoch 24/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.9495 - acc: 0.6873 - val_loss: 3.3781 - val_acc: 0.5168
# Epoch 25/50
# 14/14 [==============================] - 5s 274ms/step - loss: 2.6170 - acc: 0.5865 - val_loss: 2.3484 - val_acc: 0.5962
# Epoch 26/50
# 14/14 [==============================] - 5s 278ms/step - loss: 2.1403 - acc: 0.6397 - val_loss: 4.4460 - val_acc: 0.3654
# Epoch 27/50
# 14/14 [==============================] - 5s 277ms/step - loss: 2.7105 - acc: 0.5955 - val_loss: 3.0142 - val_acc: 0.6178
# Epoch 28/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.9645 - acc: 0.6883 - val_loss: 2.6233 - val_acc: 0.5865
# Epoch 29/50
# 14/14 [==============================] - 5s 279ms/step - loss: 1.8824 - acc: 0.6984 - val_loss: 3.7689 - val_acc: 0.4856
# Epoch 30/50
# 14/14 [==============================] - 5s 279ms/step - loss: 2.2863 - acc: 0.6439 - val_loss: 3.7233 - val_acc: 0.5865
# Epoch 31/50
# 14/14 [==============================] - 5s 271ms/step - loss: 2.2610 - acc: 0.6838 - val_loss: 3.2166 - val_acc: 0.5096
# Epoch 32/50
# 14/14 [==============================] - 5s 274ms/step - loss: 2.1109 - acc: 0.6743 - val_loss: 2.7576 - val_acc: 0.6250
# Epoch 33/50
# 14/14 [==============================] - 5s 280ms/step - loss: 1.7249 - acc: 0.7312 - val_loss: 2.7910 - val_acc: 0.6250
# Epoch 34/50
# 14/14 [==============================] - 5s 278ms/step - loss: 1.7571 - acc: 0.7033 - val_loss: 3.6278 - val_acc: 0.5745
# Epoch 35/50
# 14/14 [==============================] - 5s 277ms/step - loss: 2.0085 - acc: 0.6824 - val_loss: 2.2343 - val_acc: 0.6514
# Epoch 36/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.5721 - acc: 0.7700 - val_loss: 4.1865 - val_acc: 0.5168
# Epoch 37/50
# 14/14 [==============================] - 5s 277ms/step - loss: 2.2686 - acc: 0.6399 - val_loss: 2.3286 - val_acc: 0.6274
# Epoch 38/50
# 14/14 [==============================] - 5s 273ms/step - loss: 1.6146 - acc: 0.7573 - val_loss: 4.2331 - val_acc: 0.5481
# Epoch 39/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.8091 - acc: 0.7188 - val_loss: 2.4389 - val_acc: 0.6707
# Epoch 40/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.5291 - acc: 0.7660 - val_loss: 2.5297 - val_acc: 0.6322
# Epoch 41/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.4113 - acc: 0.7931 - val_loss: 3.8526 - val_acc: 0.4856
# Epoch 42/50
# 14/14 [==============================] - 5s 283ms/step - loss: 1.7078 - acc: 0.7482 - val_loss: 3.3172 - val_acc: 0.6106
# Epoch 43/50
# 14/14 [==============================] - 5s 278ms/step - loss: 1.6141 - acc: 0.7575 - val_loss: 2.8372 - val_acc: 0.6130
# Epoch 44/50
# 14/14 [==============================] - 5s 270ms/step - loss: 1.5436 - acc: 0.7740 - val_loss: 3.5147 - val_acc: 0.5721
# Epoch 45/50
# 14/14 [==============================] - 5s 278ms/step - loss: 1.4402 - acc: 0.8055 - val_loss: 4.0825 - val_acc: 0.6106
# Epoch 46/50
# 14/14 [==============================] - 5s 272ms/step - loss: 1.7301 - acc: 0.7545 - val_loss: 3.2899 - val_acc: 0.5913
# Epoch 47/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.7355 - acc: 0.7293 - val_loss: 4.3142 - val_acc: 0.6034
# Epoch 48/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.8749 - acc: 0.7363 - val_loss: 2.9818 - val_acc: 0.6274
# Epoch 49/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.3430 - acc: 0.8051 - val_loss: 2.3410 - val_acc: 0.6490
# Epoch 50/50
# 14/14 [==============================] - 5s 276ms/step - loss: 1.3159 - acc: 0.8149 - val_loss: 4.5966 - val_acc: 0.5745
# 4/4 [==============================] - 1s 142ms/step - loss: 4.5966 - acc: 0.5745
# --- Starting trial: run-3
# {'num_units 1': 1024, 'num_units 2': 512, 'num_units 3': 256, 'num_units 4': 128, 'dropout': 0.2, 'l2 regularizer': 0.001, 'optimizer': 'adam', 'activation func': 'gelu'}
# Epoch 1/50
# 14/14 [==============================] - 7s 312ms/step - loss: 4.0746 - acc: 0.1141 - val_loss: 3.0265 - val_acc: 0.3630
# Epoch 2/50
# 14/14 [==============================] - 5s 273ms/step - loss: 3.2743 - acc: 0.2807 - val_loss: 2.3519 - val_acc: 0.5264
# Epoch 3/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.8032 - acc: 0.3921 - val_loss: 2.1291 - val_acc: 0.5769
# Epoch 4/50
# 14/14 [==============================] - 5s 271ms/step - loss: 2.4859 - acc: 0.4692 - val_loss: 2.0336 - val_acc: 0.5817
# Epoch 5/50
# 14/14 [==============================] - 5s 271ms/step - loss: 2.2171 - acc: 0.5491 - val_loss: 2.0199 - val_acc: 0.5938
# Epoch 6/50
# 14/14 [==============================] - 5s 276ms/step - loss: 2.0694 - acc: 0.5822 - val_loss: 1.8911 - val_acc: 0.5962
# Epoch 7/50
# 14/14 [==============================] - 5s 277ms/step - loss: 1.8702 - acc: 0.6195 - val_loss: 1.8353 - val_acc: 0.6683
# Epoch 8/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.8085 - acc: 0.6442 - val_loss: 1.7728 - val_acc: 0.6635
# Epoch 9/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.6834 - acc: 0.6628 - val_loss: 1.8722 - val_acc: 0.6490
# Epoch 10/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.7299 - acc: 0.6633 - val_loss: 1.7520 - val_acc: 0.6851
# Epoch 11/50
# 14/14 [==============================] - 5s 276ms/step - loss: 1.6699 - acc: 0.6557 - val_loss: 1.7089 - val_acc: 0.6827
# Epoch 12/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.6098 - acc: 0.6884 - val_loss: 1.7043 - val_acc: 0.6587
# Epoch 13/50
# 14/14 [==============================] - 5s 278ms/step - loss: 1.5128 - acc: 0.7149 - val_loss: 1.7311 - val_acc: 0.6611
# Epoch 14/50
# 14/14 [==============================] - 5s 272ms/step - loss: 1.4381 - acc: 0.7156 - val_loss: 1.6765 - val_acc: 0.6827
# Epoch 15/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.3349 - acc: 0.7552 - val_loss: 1.7313 - val_acc: 0.6827
# Epoch 16/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.2530 - acc: 0.7675 - val_loss: 1.6089 - val_acc: 0.6971
# Epoch 17/50
# 14/14 [==============================] - 5s 277ms/step - loss: 1.2091 - acc: 0.7761 - val_loss: 1.5109 - val_acc: 0.7260
# Epoch 18/50
# 14/14 [==============================] - 5s 276ms/step - loss: 1.1117 - acc: 0.8217 - val_loss: 1.6459 - val_acc: 0.6947
# Epoch 19/50
# 14/14 [==============================] - 5s 278ms/step - loss: 1.1180 - acc: 0.8003 - val_loss: 1.7582 - val_acc: 0.6851
# Epoch 20/50
# 14/14 [==============================] - 5s 272ms/step - loss: 1.0796 - acc: 0.8186 - val_loss: 1.6152 - val_acc: 0.6875
# Epoch 21/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.0557 - acc: 0.8128 - val_loss: 1.6147 - val_acc: 0.7067
# Epoch 22/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.0298 - acc: 0.8433 - val_loss: 1.6533 - val_acc: 0.6995
# Epoch 23/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.9782 - acc: 0.8529 - val_loss: 1.6593 - val_acc: 0.6923
# Epoch 24/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.0277 - acc: 0.8296 - val_loss: 1.6592 - val_acc: 0.6899
# Epoch 25/50
# 14/14 [==============================] - 5s 282ms/step - loss: 1.0992 - acc: 0.7988 - val_loss: 1.7261 - val_acc: 0.6875
# Epoch 26/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.0767 - acc: 0.8205 - val_loss: 1.6649 - val_acc: 0.6851
# Epoch 27/50
# 14/14 [==============================] - 5s 281ms/step - loss: 1.0826 - acc: 0.8201 - val_loss: 1.7610 - val_acc: 0.6635
# Epoch 28/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.9949 - acc: 0.8255 - val_loss: 1.5541 - val_acc: 0.7091
# Epoch 29/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.9449 - acc: 0.8524 - val_loss: 1.7592 - val_acc: 0.6851
# Epoch 30/50
# 14/14 [==============================] - 5s 270ms/step - loss: 0.8716 - acc: 0.8645 - val_loss: 1.5940 - val_acc: 0.7091
# Epoch 31/50
# 14/14 [==============================] - 5s 270ms/step - loss: 0.8985 - acc: 0.8628 - val_loss: 1.5902 - val_acc: 0.7091
# Epoch 32/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.9916 - acc: 0.8356 - val_loss: 1.5552 - val_acc: 0.7139
# Epoch 33/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.8867 - acc: 0.8551 - val_loss: 1.6207 - val_acc: 0.6947
# Epoch 34/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.9749 - acc: 0.8333 - val_loss: 1.5237 - val_acc: 0.7163
# Epoch 35/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.8913 - acc: 0.8629 - val_loss: 1.5913 - val_acc: 0.7139
# Epoch 36/50
# 14/14 [==============================] - 5s 278ms/step - loss: 0.7923 - acc: 0.8849 - val_loss: 1.5059 - val_acc: 0.7284
# Epoch 37/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.7987 - acc: 0.8700 - val_loss: 1.6155 - val_acc: 0.6875
# Epoch 38/50
# 14/14 [==============================] - 5s 271ms/step - loss: 0.7850 - acc: 0.8900 - val_loss: 1.5774 - val_acc: 0.7067
# Epoch 39/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.7365 - acc: 0.8924 - val_loss: 1.5647 - val_acc: 0.7404
# Epoch 40/50
# 14/14 [==============================] - 5s 272ms/step - loss: 0.8124 - acc: 0.8794 - val_loss: 1.7123 - val_acc: 0.6851
# Epoch 41/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.8119 - acc: 0.8694 - val_loss: 1.6579 - val_acc: 0.6875
# Epoch 42/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.7207 - acc: 0.9004 - val_loss: 1.5328 - val_acc: 0.6779
# Epoch 43/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.7320 - acc: 0.8911 - val_loss: 1.6320 - val_acc: 0.6803
# Epoch 44/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.6920 - acc: 0.8972 - val_loss: 1.5153 - val_acc: 0.7188
# Epoch 45/50
# 14/14 [==============================] - 5s 282ms/step - loss: 0.7162 - acc: 0.9102 - val_loss: 1.5794 - val_acc: 0.7115
# Epoch 46/50
# 14/14 [==============================] - 5s 272ms/step - loss: 0.7073 - acc: 0.9027 - val_loss: 1.6422 - val_acc: 0.7163
# Epoch 47/50
# 14/14 [==============================] - 5s 272ms/step - loss: 0.7551 - acc: 0.8861 - val_loss: 1.7110 - val_acc: 0.6875
# Epoch 48/50
# 14/14 [==============================] - 5s 272ms/step - loss: 0.7628 - acc: 0.8738 - val_loss: 1.6054 - val_acc: 0.6947
# Epoch 49/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.6817 - acc: 0.8924 - val_loss: 1.7529 - val_acc: 0.7163
# Epoch 50/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.6581 - acc: 0.9112 - val_loss: 1.5687 - val_acc: 0.7308
# 4/4 [==============================] - 1s 134ms/step - loss: 1.5687 - acc: 0.7308
# --- Starting trial: run-4
# {'num_units 1': 1024, 'num_units 2': 512, 'num_units 3': 256, 'num_units 4': 128, 'dropout': 0.2, 'l2 regularizer': 0.001, 'optimizer': 'adam', 'activation func': 'relu'}
# Epoch 1/50
# 14/14 [==============================] - 7s 313ms/step - loss: 4.1585 - acc: 0.0956 - val_loss: 2.9716 - val_acc: 0.3822
# Epoch 2/50
# 14/14 [==============================] - 5s 275ms/step - loss: 3.3045 - acc: 0.2669 - val_loss: 2.4417 - val_acc: 0.5288
# Epoch 3/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.9525 - acc: 0.3475 - val_loss: 2.2650 - val_acc: 0.5096
# Epoch 4/50
# 14/14 [==============================] - 5s 271ms/step - loss: 2.6450 - acc: 0.4287 - val_loss: 2.0505 - val_acc: 0.5841
# Epoch 5/50
# 14/14 [==============================] - 5s 274ms/step - loss: 2.3968 - acc: 0.4665 - val_loss: 2.0342 - val_acc: 0.5505
# Epoch 6/50
# 14/14 [==============================] - 5s 277ms/step - loss: 2.3033 - acc: 0.5057 - val_loss: 1.8874 - val_acc: 0.6298
# Epoch 7/50
# 14/14 [==============================] - 5s 279ms/step - loss: 2.1099 - acc: 0.5399 - val_loss: 1.7806 - val_acc: 0.6346
# Epoch 8/50
# 14/14 [==============================] - 5s 278ms/step - loss: 1.9381 - acc: 0.5750 - val_loss: 1.7465 - val_acc: 0.6202
# Epoch 9/50
# 14/14 [==============================] - 5s 270ms/step - loss: 1.9241 - acc: 0.5833 - val_loss: 1.6956 - val_acc: 0.6394
# Epoch 10/50
# 14/14 [==============================] - 5s 277ms/step - loss: 1.7514 - acc: 0.6175 - val_loss: 1.6253 - val_acc: 0.6587
# Epoch 11/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.7213 - acc: 0.6225 - val_loss: 1.6666 - val_acc: 0.6370
# Epoch 12/50
# 14/14 [==============================] - 5s 270ms/step - loss: 1.5951 - acc: 0.6719 - val_loss: 1.6679 - val_acc: 0.6418
# Epoch 13/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.6276 - acc: 0.6584 - val_loss: 1.6120 - val_acc: 0.6731
# Epoch 14/50
# 14/14 [==============================] - 5s 272ms/step - loss: 1.6384 - acc: 0.6404 - val_loss: 1.5628 - val_acc: 0.6779
# Epoch 15/50
# 14/14 [==============================] - 5s 277ms/step - loss: 1.4118 - acc: 0.7094 - val_loss: 1.5439 - val_acc: 0.6827
# Epoch 16/50
# 14/14 [==============================] - 5s 276ms/step - loss: 1.4211 - acc: 0.6876 - val_loss: 1.5812 - val_acc: 0.6490
# Epoch 17/50
# 14/14 [==============================] - 5s 276ms/step - loss: 1.3016 - acc: 0.7552 - val_loss: 1.5655 - val_acc: 0.6779
# Epoch 18/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.3137 - acc: 0.7333 - val_loss: 1.5880 - val_acc: 0.6490
# Epoch 19/50
# 14/14 [==============================] - 5s 276ms/step - loss: 1.2864 - acc: 0.7321 - val_loss: 1.5616 - val_acc: 0.6827
# Epoch 20/50
# 14/14 [==============================] - 5s 272ms/step - loss: 1.1855 - acc: 0.7794 - val_loss: 1.5338 - val_acc: 0.6947
# Epoch 21/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.1350 - acc: 0.7704 - val_loss: 1.5437 - val_acc: 0.6995
# Epoch 22/50
# 14/14 [==============================] - 5s 276ms/step - loss: 1.1962 - acc: 0.7595 - val_loss: 1.5205 - val_acc: 0.6995
# Epoch 23/50
# 14/14 [==============================] - 5s 272ms/step - loss: 1.2099 - acc: 0.7587 - val_loss: 1.4775 - val_acc: 0.7091
# Epoch 24/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.0794 - acc: 0.7795 - val_loss: 1.4599 - val_acc: 0.6947
# Epoch 25/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.0372 - acc: 0.8017 - val_loss: 1.5356 - val_acc: 0.6947
# Epoch 26/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.0799 - acc: 0.7868 - val_loss: 1.5366 - val_acc: 0.6851
# Epoch 27/50
# 14/14 [==============================] - 5s 280ms/step - loss: 1.0134 - acc: 0.8094 - val_loss: 1.5440 - val_acc: 0.6971
# Epoch 28/50
# 14/14 [==============================] - 5s 279ms/step - loss: 0.9057 - acc: 0.8425 - val_loss: 1.6549 - val_acc: 0.6947
# Epoch 29/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.9823 - acc: 0.8085 - val_loss: 1.5595 - val_acc: 0.6827
# Epoch 30/50
# 14/14 [==============================] - 5s 272ms/step - loss: 0.8930 - acc: 0.8421 - val_loss: 1.5549 - val_acc: 0.6875
# Epoch 31/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.9128 - acc: 0.8416 - val_loss: 1.6030 - val_acc: 0.6851
# Epoch 32/50
# 14/14 [==============================] - 5s 279ms/step - loss: 0.9154 - acc: 0.8318 - val_loss: 1.5376 - val_acc: 0.6947
# Epoch 33/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.7855 - acc: 0.8645 - val_loss: 1.5454 - val_acc: 0.7115
# Epoch 34/50
# 14/14 [==============================] - 5s 278ms/step - loss: 0.8761 - acc: 0.8499 - val_loss: 1.6625 - val_acc: 0.7019
# Epoch 35/50
# 14/14 [==============================] - 5s 272ms/step - loss: 0.8643 - acc: 0.8352 - val_loss: 1.5415 - val_acc: 0.7067
# Epoch 36/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.7642 - acc: 0.8829 - val_loss: 1.6065 - val_acc: 0.6875
# Epoch 37/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.7783 - acc: 0.8650 - val_loss: 1.5924 - val_acc: 0.7332
# Epoch 38/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.7348 - acc: 0.8924 - val_loss: 1.5391 - val_acc: 0.7212
# Epoch 39/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.6941 - acc: 0.9005 - val_loss: 1.5419 - val_acc: 0.7188
# Epoch 40/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.6623 - acc: 0.9019 - val_loss: 1.5577 - val_acc: 0.7332
# Epoch 41/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.7524 - acc: 0.8769 - val_loss: 1.7387 - val_acc: 0.7043
# Epoch 42/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.8781 - acc: 0.8412 - val_loss: 1.5920 - val_acc: 0.6899
# Epoch 43/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.8665 - acc: 0.8378 - val_loss: 1.4927 - val_acc: 0.6995
# Epoch 44/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.7401 - acc: 0.8777 - val_loss: 1.5223 - val_acc: 0.7043
# Epoch 45/50
# 14/14 [==============================] - 5s 271ms/step - loss: 0.7974 - acc: 0.8639 - val_loss: 1.4867 - val_acc: 0.7260
# Epoch 46/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.7534 - acc: 0.8621 - val_loss: 1.4896 - val_acc: 0.7284
# Epoch 47/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.6853 - acc: 0.8870 - val_loss: 1.5396 - val_acc: 0.7260
# Epoch 48/50
# 14/14 [==============================] - 5s 272ms/step - loss: 0.6561 - acc: 0.9062 - val_loss: 1.4912 - val_acc: 0.7236
# Epoch 49/50
# 14/14 [==============================] - 5s 273ms/step - loss: 0.6975 - acc: 0.8822 - val_loss: 1.6920 - val_acc: 0.7115
# Epoch 50/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.7259 - acc: 0.8852 - val_loss: 1.5788 - val_acc: 0.7067
# 4/4 [==============================] - 1s 134ms/step - loss: 1.5788 - acc: 0.7067
# --- Starting trial: run-5
# {'num_units 1': 1024, 'num_units 2': 512, 'num_units 3': 256, 'num_units 4': 128, 'dropout': 0.2, 'l2 regularizer': 0.001, 'optimizer': 'adam', 'activation func': 'selu'}
# Epoch 1/50
# 14/14 [==============================] - 7s 309ms/step - loss: 6.6006 - acc: 0.1173 - val_loss: 4.2405 - val_acc: 0.2716
# Epoch 2/50
# 14/14 [==============================] - 5s 278ms/step - loss: 4.3141 - acc: 0.2874 - val_loss: 2.7507 - val_acc: 0.4471
# Epoch 3/50
# 14/14 [==============================] - 5s 276ms/step - loss: 3.5096 - acc: 0.3852 - val_loss: 2.7574 - val_acc: 0.4712
# Epoch 4/50
# 14/14 [==============================] - 5s 283ms/step - loss: 3.4358 - acc: 0.4012 - val_loss: 2.3828 - val_acc: 0.5625
# Epoch 5/50
# 14/14 [==============================] - 5s 271ms/step - loss: 3.0648 - acc: 0.4499 - val_loss: 2.2980 - val_acc: 0.5889
# Epoch 6/50
# 14/14 [==============================] - 5s 280ms/step - loss: 2.7919 - acc: 0.4876 - val_loss: 2.4146 - val_acc: 0.5962
# Epoch 7/50
# 14/14 [==============================] - 5s 274ms/step - loss: 2.8620 - acc: 0.5054 - val_loss: 2.4866 - val_acc: 0.5841
# Epoch 8/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.6824 - acc: 0.5234 - val_loss: 2.5360 - val_acc: 0.5745
# Epoch 9/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.6691 - acc: 0.5440 - val_loss: 2.3907 - val_acc: 0.5938
# Epoch 10/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.7394 - acc: 0.5276 - val_loss: 2.2652 - val_acc: 0.6178
# Epoch 11/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.7065 - acc: 0.5176 - val_loss: 2.2307 - val_acc: 0.6298
# Epoch 12/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.2665 - acc: 0.6270 - val_loss: 2.1947 - val_acc: 0.6731
# Epoch 13/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.2339 - acc: 0.6352 - val_loss: 2.1644 - val_acc: 0.6442
# Epoch 14/50
# 14/14 [==============================] - 5s 277ms/step - loss: 2.3254 - acc: 0.6180 - val_loss: 2.1912 - val_acc: 0.6274
# Epoch 15/50
# 14/14 [==============================] - 5s 275ms/step - loss: 2.2880 - acc: 0.5931 - val_loss: 2.3459 - val_acc: 0.6250
# Epoch 16/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.6112 - acc: 0.5843 - val_loss: 2.1392 - val_acc: 0.6442
# Epoch 17/50
# 14/14 [==============================] - 5s 276ms/step - loss: 2.3748 - acc: 0.5848 - val_loss: 2.0741 - val_acc: 0.6587
# Epoch 18/50
# 14/14 [==============================] - 5s 275ms/step - loss: 2.2892 - acc: 0.6353 - val_loss: 2.0595 - val_acc: 0.6562
# Epoch 19/50
# 14/14 [==============================] - 5s 277ms/step - loss: 2.2820 - acc: 0.6048 - val_loss: 2.2054 - val_acc: 0.6202
# Epoch 20/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.4263 - acc: 0.6192 - val_loss: 2.0948 - val_acc: 0.6562
# Epoch 21/50
# 14/14 [==============================] - 5s 275ms/step - loss: 2.1245 - acc: 0.6287 - val_loss: 2.1029 - val_acc: 0.6779
# Epoch 22/50
# 14/14 [==============================] - 5s 278ms/step - loss: 1.9163 - acc: 0.6988 - val_loss: 2.1989 - val_acc: 0.6923
# Epoch 23/50
# 14/14 [==============================] - 5s 273ms/step - loss: 1.9509 - acc: 0.7012 - val_loss: 2.1336 - val_acc: 0.6803
# Epoch 24/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.9270 - acc: 0.7197 - val_loss: 2.3206 - val_acc: 0.6370
# Epoch 25/50
# 14/14 [==============================] - 5s 270ms/step - loss: 2.2042 - acc: 0.6402 - val_loss: 2.1826 - val_acc: 0.6587
# Epoch 26/50
# 14/14 [==============================] - 5s 273ms/step - loss: 1.8991 - acc: 0.7051 - val_loss: 2.3931 - val_acc: 0.6587
# Epoch 27/50
# 14/14 [==============================] - 5s 279ms/step - loss: 2.1784 - acc: 0.6739 - val_loss: 2.1586 - val_acc: 0.6562
# Epoch 28/50
# 14/14 [==============================] - 5s 276ms/step - loss: 1.9109 - acc: 0.7111 - val_loss: 2.0443 - val_acc: 0.6635
# Epoch 29/50
# 14/14 [==============================] - 5s 282ms/step - loss: 1.7735 - acc: 0.7395 - val_loss: 2.0334 - val_acc: 0.7188
# Epoch 30/50
# 14/14 [==============================] - 5s 281ms/step - loss: 1.7583 - acc: 0.7407 - val_loss: 2.0257 - val_acc: 0.6971
# Epoch 31/50
# 14/14 [==============================] - 5s 290ms/step - loss: 1.6939 - acc: 0.7527 - val_loss: 2.2453 - val_acc: 0.6707
# Epoch 32/50
# 14/14 [==============================] - 10s 656ms/step - loss: 1.6868 - acc: 0.7601 - val_loss: 1.9980 - val_acc: 0.7188
# Epoch 33/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.6977 - acc: 0.7630 - val_loss: 2.1061 - val_acc: 0.7019
# Epoch 34/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.7651 - acc: 0.7308 - val_loss: 2.0447 - val_acc: 0.6875
# Epoch 35/50
# 14/14 [==============================] - 5s 266ms/step - loss: 1.8338 - acc: 0.6998 - val_loss: 2.0439 - val_acc: 0.6923
# Epoch 36/50
# 14/14 [==============================] - 5s 273ms/step - loss: 1.7335 - acc: 0.7337 - val_loss: 2.1447 - val_acc: 0.6971
# Epoch 37/50
# 14/14 [==============================] - 5s 270ms/step - loss: 1.7017 - acc: 0.7473 - val_loss: 2.0444 - val_acc: 0.7091
# Epoch 38/50
# 14/14 [==============================] - 5s 273ms/step - loss: 1.5345 - acc: 0.7788 - val_loss: 2.0391 - val_acc: 0.7091
# Epoch 39/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.4618 - acc: 0.8057 - val_loss: 2.1011 - val_acc: 0.7067
# Epoch 40/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.4198 - acc: 0.8283 - val_loss: 2.3492 - val_acc: 0.7043
# Epoch 41/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.5669 - acc: 0.7862 - val_loss: 2.1814 - val_acc: 0.6827
# Epoch 42/50
# 14/14 [==============================] - 5s 269ms/step - loss: 1.7667 - acc: 0.7195 - val_loss: 1.9467 - val_acc: 0.6971
# Epoch 43/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.6130 - acc: 0.7552 - val_loss: 2.1249 - val_acc: 0.7067
# Epoch 44/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.4565 - acc: 0.8188 - val_loss: 2.1916 - val_acc: 0.7139
# Epoch 45/50
# 14/14 [==============================] - 5s 275ms/step - loss: 1.4844 - acc: 0.7964 - val_loss: 2.0681 - val_acc: 0.6875
# Epoch 46/50
# 14/14 [==============================] - 5s 270ms/step - loss: 1.4355 - acc: 0.8057 - val_loss: 2.0137 - val_acc: 0.7139
# Epoch 47/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.4028 - acc: 0.8124 - val_loss: 2.1272 - val_acc: 0.7067
# Epoch 48/50
# 14/14 [==============================] - 5s 271ms/step - loss: 1.5017 - acc: 0.7921 - val_loss: 2.1544 - val_acc: 0.6635
# Epoch 49/50
# 14/14 [==============================] - 5s 268ms/step - loss: 1.4555 - acc: 0.7817 - val_loss: 2.1664 - val_acc: 0.7139
# Epoch 50/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.4168 - acc: 0.8037 - val_loss: 2.0073 - val_acc: 0.7067
# 4/4 [==============================] - 1s 132ms/step - loss: 2.0073 - acc: 0.7067
# --- Starting trial: run-6
# {'num_units 1': 1024, 'num_units 2': 512, 'num_units 3': 256, 'num_units 4': 128, 'dropout': 0.2, 'l2 regularizer': 0.001, 'optimizer': 'sgd', 'activation func': 'gelu'}
# Epoch 1/50
# 14/14 [==============================] - 7s 311ms/step - loss: 4.2979 - acc: 0.0582 - val_loss: 3.9025 - val_acc: 0.1611
# Epoch 2/50
# 14/14 [==============================] - 5s 272ms/step - loss: 4.0275 - acc: 0.0801 - val_loss: 3.7673 - val_acc: 0.2308
# Epoch 3/50
# 14/14 [==============================] - 5s 269ms/step - loss: 3.8960 - acc: 0.1379 - val_loss: 3.5776 - val_acc: 0.3029
# Epoch 4/50
# 14/14 [==============================] - 5s 273ms/step - loss: 3.7701 - acc: 0.1718 - val_loss: 3.4598 - val_acc: 0.3582
# Epoch 5/50
# 14/14 [==============================] - 5s 274ms/step - loss: 3.7122 - acc: 0.1840 - val_loss: 3.2718 - val_acc: 0.3942
# Epoch 6/50
# 14/14 [==============================] - 5s 273ms/step - loss: 3.5485 - acc: 0.2389 - val_loss: 3.1420 - val_acc: 0.3918
# Epoch 7/50
# 14/14 [==============================] - 5s 270ms/step - loss: 3.4742 - acc: 0.2523 - val_loss: 2.9984 - val_acc: 0.4351
# Epoch 8/50
# 14/14 [==============================] - 5s 273ms/step - loss: 3.3601 - acc: 0.2957 - val_loss: 2.8880 - val_acc: 0.4303
# Epoch 9/50
# 14/14 [==============================] - 5s 274ms/step - loss: 3.2588 - acc: 0.3243 - val_loss: 2.7813 - val_acc: 0.5000
# Epoch 10/50
# 14/14 [==============================] - 5s 275ms/step - loss: 3.1699 - acc: 0.3375 - val_loss: 2.6573 - val_acc: 0.5000
# Epoch 11/50
# 14/14 [==============================] - 5s 274ms/step - loss: 3.0922 - acc: 0.3709 - val_loss: 2.6994 - val_acc: 0.4736
# Epoch 12/50
# 14/14 [==============================] - 5s 278ms/step - loss: 3.0658 - acc: 0.3623 - val_loss: 2.5745 - val_acc: 0.5120
# Epoch 13/50
# 14/14 [==============================] - 5s 268ms/step - loss: 2.9788 - acc: 0.3864 - val_loss: 2.4938 - val_acc: 0.5120
# Epoch 14/50
# 14/14 [==============================] - 5s 271ms/step - loss: 2.9524 - acc: 0.3991 - val_loss: 2.4432 - val_acc: 0.5385
# Epoch 15/50
# 14/14 [==============================] - 5s 268ms/step - loss: 2.8058 - acc: 0.4360 - val_loss: 2.4356 - val_acc: 0.5745
# Epoch 16/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.8083 - acc: 0.4332 - val_loss: 2.4059 - val_acc: 0.5120
# Epoch 17/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.7786 - acc: 0.4544 - val_loss: 2.4293 - val_acc: 0.5457
# Epoch 18/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.8245 - acc: 0.4214 - val_loss: 2.3220 - val_acc: 0.5913
# Epoch 19/50
# 14/14 [==============================] - 5s 268ms/step - loss: 2.7616 - acc: 0.4491 - val_loss: 2.2830 - val_acc: 0.6082
# Epoch 20/50
# 14/14 [==============================] - 5s 267ms/step - loss: 2.5985 - acc: 0.4866 - val_loss: 2.2709 - val_acc: 0.6130
# Epoch 21/50
# 14/14 [==============================] - 5s 278ms/step - loss: 2.5526 - acc: 0.5020 - val_loss: 2.2891 - val_acc: 0.5865
# Epoch 22/50
# 14/14 [==============================] - 5s 276ms/step - loss: 2.6667 - acc: 0.4915 - val_loss: 2.2471 - val_acc: 0.6010
# Epoch 23/50
# 14/14 [==============================] - 5s 269ms/step - loss: 2.5362 - acc: 0.5038 - val_loss: 2.3592 - val_acc: 0.6034
# Epoch 24/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.5369 - acc: 0.5140 - val_loss: 2.1993 - val_acc: 0.6058
# Epoch 25/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.4579 - acc: 0.5300 - val_loss: 2.2253 - val_acc: 0.6106
# Epoch 26/50
# 14/14 [==============================] - 5s 267ms/step - loss: 2.4684 - acc: 0.5521 - val_loss: 2.1846 - val_acc: 0.6154
# Epoch 27/50
# 14/14 [==============================] - 5s 270ms/step - loss: 2.4662 - acc: 0.5426 - val_loss: 2.2607 - val_acc: 0.5553
# Epoch 28/50
# 14/14 [==============================] - 5s 277ms/step - loss: 2.4519 - acc: 0.5297 - val_loss: 2.1559 - val_acc: 0.6346
# Epoch 29/50
# 14/14 [==============================] - 5s 271ms/step - loss: 2.3528 - acc: 0.5584 - val_loss: 2.1361 - val_acc: 0.6394
# Epoch 30/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.3345 - acc: 0.5863 - val_loss: 2.1111 - val_acc: 0.6322
# Epoch 31/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.3414 - acc: 0.5539 - val_loss: 2.2412 - val_acc: 0.6106
# Epoch 32/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.2949 - acc: 0.5812 - val_loss: 2.1331 - val_acc: 0.6442
# Epoch 33/50
# 14/14 [==============================] - 5s 276ms/step - loss: 2.2845 - acc: 0.5688 - val_loss: 2.0847 - val_acc: 0.6562
# Epoch 34/50
# 14/14 [==============================] - 5s 269ms/step - loss: 2.2913 - acc: 0.5707 - val_loss: 2.1217 - val_acc: 0.6370
# Epoch 35/50
# 14/14 [==============================] - 5s 271ms/step - loss: 2.2743 - acc: 0.5982 - val_loss: 2.1684 - val_acc: 0.6346
# Epoch 36/50
# 14/14 [==============================] - 5s 265ms/step - loss: 2.2985 - acc: 0.5907 - val_loss: 2.2200 - val_acc: 0.6154
# Epoch 37/50
# 14/14 [==============================] - 5s 270ms/step - loss: 2.2687 - acc: 0.5960 - val_loss: 2.2531 - val_acc: 0.5938
# Epoch 38/50
# 14/14 [==============================] - 5s 271ms/step - loss: 2.2411 - acc: 0.6053 - val_loss: 2.0731 - val_acc: 0.6611
# Epoch 39/50
# 14/14 [==============================] - 5s 274ms/step - loss: 2.1522 - acc: 0.6414 - val_loss: 2.1454 - val_acc: 0.6490
# Epoch 40/50
# 14/14 [==============================] - 5s 274ms/step - loss: 2.1965 - acc: 0.6100 - val_loss: 2.1474 - val_acc: 0.6202
# Epoch 41/50
# 14/14 [==============================] - 5s 273ms/step - loss: 2.1814 - acc: 0.6115 - val_loss: 2.3151 - val_acc: 0.5481
# Epoch 42/50
# 14/14 [==============================] - 5s 268ms/step - loss: 2.1773 - acc: 0.6082 - val_loss: 2.0710 - val_acc: 0.6538
# Epoch 43/50
# 14/14 [==============================] - 5s 272ms/step - loss: 2.1078 - acc: 0.6390 - val_loss: 2.2442 - val_acc: 0.5865
# Epoch 44/50
# 14/14 [==============================] - 5s 279ms/step - loss: 2.1651 - acc: 0.6064 - val_loss: 2.0792 - val_acc: 0.6442
# Epoch 45/50
# 14/14 [==============================] - 5s 275ms/step - loss: 2.1765 - acc: 0.6140 - val_loss: 2.0578 - val_acc: 0.6514
# Epoch 46/50
# 14/14 [==============================] - 5s 274ms/step - loss: 2.1018 - acc: 0.6289 - val_loss: 2.2468 - val_acc: 0.6274
# Epoch 47/50
# 14/14 [==============================] - 5s 271ms/step - loss: 2.1555 - acc: 0.6147 - val_loss: 2.2359 - val_acc: 0.6130
# Epoch 48/50
# ...
# Epoch 37/50
# 14/14 [==============================] - 5s 277ms/step - loss: 10.8489 - acc: 0.2272 - val_loss: 10.3248 - val_acc: 0.4423
# Epoch 38/50
# 14/14 [==============================] - 5s 274ms/step - loss: 10.7417 - acc: 0.2193 - val_loss: 10.2534 - val_acc: 0.4399
# Epoch 39/50
# 14/14 [==============================] - 5s 273ms/step - loss: 10.6780 - acc: 0.2509 - val_loss: 10.1579 - val_acc: 0.4399
# Epoch 40/50
# 14/14 [==============================] - 5s 271ms/step - loss: 10.6055 - acc: 0.2651 - val_loss: 10.0939 - val_acc: 0.4519
# Epoch 41/50
# 14/14 [==============================] - 5s 273ms/step - loss: 10.5331 - acc: 0.2624 - val_loss: 10.0199 - val_acc: 0.4447
# Epoch 42/50
# 14/14 [==============================] - 5s 277ms/step - loss: 10.4782 - acc: 0.2637 - val_loss: 9.9398 - val_acc: 0.4639
# Epoch 43/50
# 14/14 [==============================] - 5s 275ms/step - loss: 10.4238 - acc: 0.2484 - val_loss: 9.8742 - val_acc: 0.4736
# Epoch 44/50
# 14/14 [==============================] - 5s 276ms/step - loss: 10.3368 - acc: 0.2878 - val_loss: 9.8097 - val_acc: 0.4904
# Epoch 45/50
# 14/14 [==============================] - 5s 269ms/step - loss: 10.2430 - acc: 0.2814 - val_loss: 9.7325 - val_acc: 0.4760
# Epoch 46/50
# 14/14 [==============================] - 5s 270ms/step - loss: 10.2541 - acc: 0.2631 - val_loss: 9.6783 - val_acc: 0.4904
# Epoch 47/50
# 14/14 [==============================] - 5s 268ms/step - loss: 10.1302 - acc: 0.2894 - val_loss: 9.6187 - val_acc: 0.5072
# Epoch 48/50
# 14/14 [==============================] - 5s 273ms/step - loss: 10.0826 - acc: 0.2835 - val_loss: 9.5369 - val_acc: 0.5144
# Epoch 49/50
# 14/14 [==============================] - 5s 269ms/step - loss: 9.9772 - acc: 0.2993 - val_loss: 9.4606 - val_acc: 0.5048
# Epoch 50/50
# 14/14 [==============================] - 5s 276ms/step - loss: 9.9811 - acc: 0.2959 - val_loss: 9.4062 - val_acc: 0.4976
# 4/4 [==============================] - 1s 136ms/step - loss: 9.4062 - acc: 0.4976
# --- Starting trial: run-34
# {'num_units 1': 1024, 'num_units 2': 512, 'num_units 3': 256, 'num_units 4': 128, 'dropout': 0.5, 'l2 regularizer': 0.01, 'optimizer': 'sgd', 'activation func': 'relu'}
# Epoch 1/50
# 14/14 [==============================] - 7s 313ms/step - loss: 14.7370 - acc: 0.0564 - val_loss: 13.1589 - val_acc: 0.0889
# Epoch 2/50
# 14/14 [==============================] - 5s 275ms/step - loss: 13.8514 - acc: 0.0417 - val_loss: 13.0869 - val_acc: 0.0793
# Epoch 3/50
# 14/14 [==============================] - 5s 272ms/step - loss: 13.5546 - acc: 0.0473 - val_loss: 13.0279 - val_acc: 0.1082
# Epoch 4/50
# 14/14 [==============================] - 5s 277ms/step - loss: 13.3506 - acc: 0.0511 - val_loss: 12.9582 - val_acc: 0.1466
# Epoch 5/50
# 14/14 [==============================] - 5s 269ms/step - loss: 13.2234 - acc: 0.0539 - val_loss: 12.9013 - val_acc: 0.1827
# Epoch 6/50
# 14/14 [==============================] - 5s 274ms/step - loss: 13.1619 - acc: 0.0541 - val_loss: 12.8400 - val_acc: 0.1683
# Epoch 7/50
# 14/14 [==============================] - 5s 277ms/step - loss: 13.0436 - acc: 0.0531 - val_loss: 12.7840 - val_acc: 0.1562
# Epoch 8/50
# 14/14 [==============================] - 5s 273ms/step - loss: 12.9677 - acc: 0.0596 - val_loss: 12.7235 - val_acc: 0.1875
# Epoch 9/50
# 14/14 [==============================] - 5s 274ms/step - loss: 12.8795 - acc: 0.0778 - val_loss: 12.6668 - val_acc: 0.1827
# Epoch 10/50
# 14/14 [==============================] - 5s 270ms/step - loss: 12.8059 - acc: 0.0651 - val_loss: 12.6086 - val_acc: 0.1899
# Epoch 11/50
# 14/14 [==============================] - 5s 273ms/step - loss: 12.7481 - acc: 0.0610 - val_loss: 12.5500 - val_acc: 0.1827
# Epoch 12/50
# 14/14 [==============================] - 5s 274ms/step - loss: 12.6954 - acc: 0.0597 - val_loss: 12.4960 - val_acc: 0.2019
# Epoch 13/50
# 14/14 [==============================] - 5s 268ms/step - loss: 12.6109 - acc: 0.0709 - val_loss: 12.4382 - val_acc: 0.2308
# Epoch 14/50
# 14/14 [==============================] - 5s 272ms/step - loss: 12.5351 - acc: 0.0743 - val_loss: 12.3839 - val_acc: 0.2500
# Epoch 15/50
# 14/14 [==============================] - 5s 272ms/step - loss: 12.4653 - acc: 0.0658 - val_loss: 12.3318 - val_acc: 0.2236
# Epoch 16/50
# 14/14 [==============================] - 5s 270ms/step - loss: 12.4164 - acc: 0.0772 - val_loss: 12.2714 - val_acc: 0.2212
# Epoch 17/50
# 14/14 [==============================] - 5s 269ms/step - loss: 12.3631 - acc: 0.0625 - val_loss: 12.2153 - val_acc: 0.1995
# Epoch 18/50
# 14/14 [==============================] - 5s 269ms/step - loss: 12.2953 - acc: 0.0792 - val_loss: 12.1573 - val_acc: 0.2067
# Epoch 19/50
# 14/14 [==============================] - 5s 271ms/step - loss: 12.2168 - acc: 0.0809 - val_loss: 12.0911 - val_acc: 0.2332
# Epoch 20/50
# 14/14 [==============================] - 5s 269ms/step - loss: 12.1850 - acc: 0.0737 - val_loss: 12.0262 - val_acc: 0.2476
# Epoch 21/50
# 14/14 [==============================] - 5s 273ms/step - loss: 12.1096 - acc: 0.0896 - val_loss: 11.9645 - val_acc: 0.2620
# Epoch 22/50
# 14/14 [==============================] - 5s 273ms/step - loss: 12.0439 - acc: 0.0932 - val_loss: 11.8989 - val_acc: 0.2837
# Epoch 23/50
# 14/14 [==============================] - 5s 270ms/step - loss: 12.0043 - acc: 0.0730 - val_loss: 11.8458 - val_acc: 0.2548
# Epoch 24/50
# 14/14 [==============================] - 5s 271ms/step - loss: 11.9158 - acc: 0.0915 - val_loss: 11.7858 - val_acc: 0.2572
# Epoch 25/50
# 14/14 [==============================] - 5s 267ms/step - loss: 11.8589 - acc: 0.0938 - val_loss: 11.7163 - val_acc: 0.2885
# Epoch 26/50
# 14/14 [==============================] - 5s 273ms/step - loss: 11.7917 - acc: 0.0919 - val_loss: 11.6473 - val_acc: 0.3005
# Epoch 27/50
# 14/14 [==============================] - 5s 269ms/step - loss: 11.7331 - acc: 0.0952 - val_loss: 11.5845 - val_acc: 0.2885
# Epoch 28/50
# 14/14 [==============================] - 5s 273ms/step - loss: 11.7082 - acc: 0.0922 - val_loss: 11.5222 - val_acc: 0.3221
# Epoch 29/50
# 14/14 [==============================] - 5s 269ms/step - loss: 11.6274 - acc: 0.1102 - val_loss: 11.4481 - val_acc: 0.2909
# Epoch 30/50
# 14/14 [==============================] - 5s 270ms/step - loss: 11.5675 - acc: 0.1129 - val_loss: 11.3816 - val_acc: 0.2788
# Epoch 31/50
# 14/14 [==============================] - 5s 275ms/step - loss: 11.5121 - acc: 0.1202 - val_loss: 11.3206 - val_acc: 0.3029
# Epoch 32/50
# 14/14 [==============================] - 5s 270ms/step - loss: 11.4468 - acc: 0.1104 - val_loss: 11.2356 - val_acc: 0.2668
# Epoch 33/50
# 14/14 [==============================] - 5s 269ms/step - loss: 11.3800 - acc: 0.1299 - val_loss: 11.1822 - val_acc: 0.2957
# Epoch 34/50
# 14/14 [==============================] - 5s 272ms/step - loss: 11.3586 - acc: 0.1073 - val_loss: 11.1217 - val_acc: 0.2885
# Epoch 35/50
# 14/14 [==============================] - 5s 274ms/step - loss: 11.2722 - acc: 0.1142 - val_loss: 11.0619 - val_acc: 0.2812
# Epoch 36/50
# 14/14 [==============================] - 5s 276ms/step - loss: 11.2457 - acc: 0.1321 - val_loss: 10.9902 - val_acc: 0.2981
# Epoch 37/50
# 14/14 [==============================] - 5s 266ms/step - loss: 11.1760 - acc: 0.1150 - val_loss: 10.9342 - val_acc: 0.2885
# Epoch 38/50
# 14/14 [==============================] - 5s 270ms/step - loss: 11.1124 - acc: 0.1353 - val_loss: 10.8605 - val_acc: 0.2812
# Epoch 39/50
# 14/14 [==============================] - 5s 269ms/step - loss: 11.0437 - acc: 0.1181 - val_loss: 10.7795 - val_acc: 0.2837
# Epoch 40/50
# 14/14 [==============================] - 5s 270ms/step - loss: 10.9578 - acc: 0.1462 - val_loss: 10.7222 - val_acc: 0.2885
# Epoch 41/50
# 14/14 [==============================] - 5s 271ms/step - loss: 10.9050 - acc: 0.1643 - val_loss: 10.6519 - val_acc: 0.3077
# Epoch 42/50
# 14/14 [==============================] - 5s 274ms/step - loss: 10.8609 - acc: 0.1415 - val_loss: 10.5832 - val_acc: 0.3413
# Epoch 43/50
# 14/14 [==============================] - 5s 270ms/step - loss: 10.7975 - acc: 0.1559 - val_loss: 10.5159 - val_acc: 0.3221
# Epoch 44/50
# 14/14 [==============================] - 5s 274ms/step - loss: 10.7717 - acc: 0.1540 - val_loss: 10.4487 - val_acc: 0.3486
# Epoch 45/50
# 14/14 [==============================] - 5s 274ms/step - loss: 10.7410 - acc: 0.1416 - val_loss: 10.3951 - val_acc: 0.3558
# Epoch 46/50
# 14/14 [==============================] - 5s 273ms/step - loss: 10.6544 - acc: 0.1431 - val_loss: 10.3333 - val_acc: 0.3534
# Epoch 47/50
# 14/14 [==============================] - 5s 272ms/step - loss: 10.6042 - acc: 0.1410 - val_loss: 10.2716 - val_acc: 0.3606
# Epoch 48/50
# 14/14 [==============================] - 5s 273ms/step - loss: 10.5331 - acc: 0.1689 - val_loss: 10.1962 - val_acc: 0.3630
# Epoch 49/50
# 14/14 [==============================] - 5s 278ms/step - loss: 10.4319 - acc: 0.1900 - val_loss: 10.1356 - val_acc: 0.3438
# Epoch 50/50
# 14/14 [==============================] - 5s 272ms/step - loss: 10.4030 - acc: 0.1740 - val_loss: 10.0516 - val_acc: 0.3510
# 4/4 [==============================] - 1s 134ms/step - loss: 10.0516 - acc: 0.3510
# --- Starting trial: run-35
# {'num_units 1': 1024, 'num_units 2': 512, 'num_units 3': 256, 'num_units 4': 128, 'dropout': 0.5, 'l2 regularizer': 0.01, 'optimizer': 'sgd', 'activation func': 'selu'}
# Epoch 1/50
# 14/14 [==============================] - 8s 316ms/step - loss: 19.2174 - acc: 0.0491 - val_loss: 13.9840 - val_acc: 0.1202
# Epoch 2/50
# 14/14 [==============================] - 5s 274ms/step - loss: 18.1440 - acc: 0.0732 - val_loss: 14.5776 - val_acc: 0.0889
# Epoch 3/50
# 14/14 [==============================] - 5s 276ms/step - loss: 16.7826 - acc: 0.0844 - val_loss: 13.3460 - val_acc: 0.1899
# Epoch 4/50
# 14/14 [==============================] - 5s 272ms/step - loss: 16.0685 - acc: 0.0960 - val_loss: 12.7994 - val_acc: 0.2115
# Epoch 5/50
# 14/14 [==============================] - 5s 275ms/step - loss: 15.6912 - acc: 0.0980 - val_loss: 12.3944 - val_acc: 0.2332
# Epoch 6/50
# 14/14 [==============================] - 5s 271ms/step - loss: 14.7718 - acc: 0.1188 - val_loss: 12.9665 - val_acc: 0.1538
# Epoch 7/50
# 14/14 [==============================] - 5s 273ms/step - loss: 14.9493 - acc: 0.1143 - val_loss: 12.5241 - val_acc: 0.1947
# Epoch 8/50
# 14/14 [==============================] - 5s 269ms/step - loss: 14.3128 - acc: 0.1385 - val_loss: 12.1960 - val_acc: 0.2861
# Epoch 9/50
# 14/14 [==============================] - 5s 269ms/step - loss: 14.1416 - acc: 0.1342 - val_loss: 11.6747 - val_acc: 0.3822
# Epoch 10/50
# 14/14 [==============================] - 5s 269ms/step - loss: 13.8666 - acc: 0.1551 - val_loss: 11.5025 - val_acc: 0.4231
# Epoch 11/50
# 14/14 [==============================] - 5s 267ms/step - loss: 13.6061 - acc: 0.1692 - val_loss: 11.5628 - val_acc: 0.3630
# Epoch 12/50
# 14/14 [==============================] - 5s 269ms/step - loss: 13.4650 - acc: 0.1794 - val_loss: 11.3533 - val_acc: 0.4135
# Epoch 13/50
# 14/14 [==============================] - 5s 273ms/step - loss: 13.2191 - acc: 0.1973 - val_loss: 11.3605 - val_acc: 0.3486
# Epoch 14/50
# 14/14 [==============================] - 5s 272ms/step - loss: 12.9965 - acc: 0.2104 - val_loss: 11.2769 - val_acc: 0.3942
# Epoch 15/50
# 14/14 [==============================] - 5s 276ms/step - loss: 12.8902 - acc: 0.1950 - val_loss: 11.0914 - val_acc: 0.4279
# Epoch 16/50
# 14/14 [==============================] - 5s 272ms/step - loss: 12.7394 - acc: 0.2310 - val_loss: 10.8763 - val_acc: 0.5024
# Epoch 17/50
# 14/14 [==============================] - 5s 270ms/step - loss: 12.5708 - acc: 0.2418 - val_loss: 10.8568 - val_acc: 0.4760
# Epoch 18/50
# 14/14 [==============================] - 5s 268ms/step - loss: 12.2849 - acc: 0.2579 - val_loss: 10.7490 - val_acc: 0.4952
# Epoch 19/50
# 14/14 [==============================] - 5s 272ms/step - loss: 12.1669 - acc: 0.2560 - val_loss: 10.5951 - val_acc: 0.5216
# Epoch 20/50
# 14/14 [==============================] - 5s 271ms/step - loss: 12.1395 - acc: 0.2611 - val_loss: 10.6829 - val_acc: 0.5120
# Epoch 21/50
# 14/14 [==============================] - 5s 278ms/step - loss: 12.1459 - acc: 0.2399 - val_loss: 10.5654 - val_acc: 0.4856
# Epoch 22/50
# 14/14 [==============================] - 5s 272ms/step - loss: 11.8642 - acc: 0.2581 - val_loss: 10.4951 - val_acc: 0.5433
# Epoch 23/50
# 14/14 [==============================] - 5s 268ms/step - loss: 11.7689 - acc: 0.2887 - val_loss: 10.3222 - val_acc: 0.5361
# Epoch 24/50
# 14/14 [==============================] - 5s 272ms/step - loss: 11.6008 - acc: 0.2991 - val_loss: 10.4134 - val_acc: 0.4856
# Epoch 25/50
# 14/14 [==============================] - 5s 272ms/step - loss: 11.4674 - acc: 0.3312 - val_loss: 10.2488 - val_acc: 0.5288
# Epoch 26/50
# 14/14 [==============================] - 5s 270ms/step - loss: 11.4573 - acc: 0.3176 - val_loss: 10.1722 - val_acc: 0.5433
# Epoch 27/50
# 14/14 [==============================] - 5s 271ms/step - loss: 11.2775 - acc: 0.3051 - val_loss: 10.3045 - val_acc: 0.4928
# Epoch 28/50
# 14/14 [==============================] - 5s 271ms/step - loss: 11.3391 - acc: 0.3013 - val_loss: 10.2258 - val_acc: 0.4663
# Epoch 29/50
# 14/14 [==============================] - 5s 272ms/step - loss: 11.1357 - acc: 0.3099 - val_loss: 10.0362 - val_acc: 0.5721
# Epoch 30/50
# 14/14 [==============================] - 5s 274ms/step - loss: 11.1281 - acc: 0.3214 - val_loss: 10.1104 - val_acc: 0.5120
# Epoch 31/50
# 14/14 [==============================] - 5s 275ms/step - loss: 11.0419 - acc: 0.3295 - val_loss: 9.8284 - val_acc: 0.5962
# Epoch 32/50
# 14/14 [==============================] - 5s 272ms/step - loss: 10.9952 - acc: 0.3267 - val_loss: 9.8173 - val_acc: 0.5817
# Epoch 33/50
# 14/14 [==============================] - 5s 267ms/step - loss: 10.7765 - acc: 0.3529 - val_loss: 9.7247 - val_acc: 0.5697
# Epoch 34/50
# 14/14 [==============================] - 5s 272ms/step - loss: 10.7651 - acc: 0.3469 - val_loss: 9.8535 - val_acc: 0.5457
# Epoch 35/50
# 14/14 [==============================] - 5s 273ms/step - loss: 10.7107 - acc: 0.3339 - val_loss: 9.8139 - val_acc: 0.5409
# Epoch 36/50
# 14/14 [==============================] - 5s 270ms/step - loss: 10.7414 - acc: 0.3417 - val_loss: 9.7261 - val_acc: 0.5481
# Epoch 37/50
# 14/14 [==============================] - 5s 269ms/step - loss: 10.5221 - acc: 0.3750 - val_loss: 9.7484 - val_acc: 0.5240
# Epoch 38/50
# 14/14 [==============================] - 5s 270ms/step - loss: 10.5869 - acc: 0.3360 - val_loss: 9.5263 - val_acc: 0.5649
# Epoch 39/50
# 14/14 [==============================] - 5s 271ms/step - loss: 10.2951 - acc: 0.3960 - val_loss: 9.4618 - val_acc: 0.5817
# Epoch 40/50
# 14/14 [==============================] - 5s 270ms/step - loss: 10.3276 - acc: 0.3529 - val_loss: 9.3624 - val_acc: 0.5865
# Epoch 41/50
# 14/14 [==============================] - 5s 277ms/step - loss: 10.1739 - acc: 0.3939 - val_loss: 9.3265 - val_acc: 0.5841
# Epoch 42/50
# 14/14 [==============================] - 5s 269ms/step - loss: 10.1766 - acc: 0.3715 - val_loss: 9.2579 - val_acc: 0.5769
# Epoch 43/50
# 14/14 [==============================] - 5s 270ms/step - loss: 10.0766 - acc: 0.3858 - val_loss: 9.3253 - val_acc: 0.5625
# Epoch 44/50
# 14/14 [==============================] - 5s 271ms/step - loss: 9.9601 - acc: 0.3810 - val_loss: 9.2007 - val_acc: 0.5962
# Epoch 45/50
# 14/14 [==============================] - 5s 269ms/step - loss: 9.8343 - acc: 0.4247 - val_loss: 9.0710 - val_acc: 0.6154
# Epoch 46/50
# 14/14 [==============================] - 5s 268ms/step - loss: 9.8621 - acc: 0.4086 - val_loss: 9.1061 - val_acc: 0.5986
# Epoch 47/50
# 14/14 [==============================] - 5s 268ms/step - loss: 9.8920 - acc: 0.3918 - val_loss: 9.0452 - val_acc: 0.5938
# Epoch 48/50
# 14/14 [==============================] - 5s 268ms/step - loss: 9.6751 - acc: 0.4417 - val_loss: 9.0171 - val_acc: 0.5745
# Epoch 49/50
# 14/14 [==============================] - 5s 270ms/step - loss: 9.5881 - acc: 0.4308 - val_loss: 8.9639 - val_acc: 0.5889
# Epoch 50/50
# 14/14 [==============================] - 5s 271ms/step - loss: 9.5723 - acc: 0.4399 - val_loss: 8.8902 - val_acc: 0.5986
# 4/4 [==============================] - 1s 139ms/step - loss: 8.8902 - acc: 0.5986

# %%
# %tensorboard --logdir logs/hparam_tuning --host localhost
# Out:
#       <iframe id="tensorboard-frame-26d83d0c5d07f391" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-26d83d0c5d07f391");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# It can be seen from tensorboard results that these are the best params for the model so the final model is re-created.

# %% [markdown]
# ## Final Model
# Best params are:
#
# - NUM_UNITS_1 = 1024
# - NUM_UNITS_2 = 512
# - NUM_UNITS_3 = 256
# - NUM_UNITS_4 = 128
# - DROPOUT = 0.2
# - ACTIVATION = gelu
# - OPTIMIZER = RMSprop
#
# Reaching a validation accuracy of 73%

# %%
input_shape = (150, 150, 3)
num_classes = 21


def final_model():
    base_model = ResNet50(include_top = False, weights = 'imagenet', input_shape = input_shape, pooling='avg')


    # Freeze the base_model
    base_model.trainable = False

    # Create new model on top
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)  # Apply random data augmentation


    x = base_model(x, training=False)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(1024, activation='gelu', input_dim=512)(x)
    x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
    x = keras.layers.Dense(512, activation='gelu', kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_L2]))(x)
    x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
    x = keras.layers.Dense(256, activation='gelu', kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_L2]))(x)
    x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
    x = keras.layers.Dense(128, activation='gelu')(x)
    x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
    outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
    model = keras.Model(inputs, outputs)
    
    # sgd=SGD(lr=learn_rate,momentum=.9,nesterov=False)

#     optimizer = keras.optimizers.Adam(lr=3e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

    # lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    #     initial_learning_rate=1e-2,
    #     decay_steps=10000,
    #     decay_rate=0.9)
    # optimizer = keras.optimizers.SGD(learning_rate=lr_schedule)
    model.compile(
                  loss='sparse_categorical_crossentropy', 
                  metrics=['acc'],
                  optimizer='RMSprop'
             )
    
    return model

# %%
model = final_model()
history = model.fit(train_ds,epochs=50,validation_data=val_ds)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 8s 332ms/step - loss: 12.2875 - acc: 0.1040 - val_loss: 10.3415 - val_acc: 0.1130
# Epoch 2/50
# 14/14 [==============================] - 5s 297ms/step - loss: 8.7673 - acc: 0.2160 - val_loss: 6.9521 - val_acc: 0.3029
# Epoch 3/50
# 14/14 [==============================] - 5s 282ms/step - loss: 6.5673 - acc: 0.3434 - val_loss: 5.4088 - val_acc: 0.4231
# Epoch 4/50
# 14/14 [==============================] - 5s 294ms/step - loss: 5.1463 - acc: 0.4651 - val_loss: 4.5305 - val_acc: 0.4688
# Epoch 5/50
# 14/14 [==============================] - 5s 293ms/step - loss: 4.3173 - acc: 0.4965 - val_loss: 4.3857 - val_acc: 0.4712
# Epoch 6/50
# 14/14 [==============================] - 5s 294ms/step - loss: 3.7547 - acc: 0.5317 - val_loss: 3.2225 - val_acc: 0.6106
# Epoch 7/50
# 14/14 [==============================] - 5s 291ms/step - loss: 3.1907 - acc: 0.5703 - val_loss: 4.4394 - val_acc: 0.4399
# Epoch 8/50
# 14/14 [==============================] - 5s 294ms/step - loss: 3.2365 - acc: 0.5516 - val_loss: 3.5377 - val_acc: 0.4567
# Epoch 9/50
# 14/14 [==============================] - 5s 293ms/step - loss: 2.7014 - acc: 0.5910 - val_loss: 2.9019 - val_acc: 0.5697
# Epoch 10/50
# 14/14 [==============================] - 5s 281ms/step - loss: 2.3789 - acc: 0.6337 - val_loss: 2.7987 - val_acc: 0.5433
# Epoch 11/50
# 14/14 [==============================] - 5s 284ms/step - loss: 2.2518 - acc: 0.6146 - val_loss: 4.0056 - val_acc: 0.4062
# Epoch 12/50
# 14/14 [==============================] - 5s 282ms/step - loss: 2.2650 - acc: 0.6136 - val_loss: 2.1493 - val_acc: 0.6635
# Epoch 13/50
# 14/14 [==============================] - 5s 289ms/step - loss: 1.6881 - acc: 0.7192 - val_loss: 2.5878 - val_acc: 0.5913
# Epoch 14/50
# 14/14 [==============================] - 5s 286ms/step - loss: 1.9922 - acc: 0.6338 - val_loss: 2.7064 - val_acc: 0.5168
# Epoch 15/50
# 14/14 [==============================] - 5s 289ms/step - loss: 1.7716 - acc: 0.6800 - val_loss: 2.7016 - val_acc: 0.5601
# Epoch 16/50
# 14/14 [==============================] - 5s 274ms/step - loss: 1.6077 - acc: 0.7271 - val_loss: 2.6306 - val_acc: 0.5505
# Epoch 17/50
# 14/14 [==============================] - 5s 281ms/step - loss: 1.7025 - acc: 0.6930 - val_loss: 2.8601 - val_acc: 0.5745
# Epoch 18/50
# 14/14 [==============================] - 5s 272ms/step - loss: 1.5848 - acc: 0.7122 - val_loss: 2.3385 - val_acc: 0.6058
# Epoch 19/50
# 14/14 [==============================] - 5s 279ms/step - loss: 1.3849 - acc: 0.7451 - val_loss: 2.2146 - val_acc: 0.6106
# Epoch 20/50
# 14/14 [==============================] - 5s 286ms/step - loss: 1.3486 - acc: 0.7308 - val_loss: 2.2299 - val_acc: 0.6058
# Epoch 21/50
# 14/14 [==============================] - 5s 283ms/step - loss: 1.3824 - acc: 0.7409 - val_loss: 2.2305 - val_acc: 0.6202
# Epoch 22/50
# 14/14 [==============================] - 5s 280ms/step - loss: 1.2344 - acc: 0.7799 - val_loss: 1.5281 - val_acc: 0.7091
# Epoch 23/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.9964 - acc: 0.8098 - val_loss: 3.3492 - val_acc: 0.4880
# Epoch 24/50
# 14/14 [==============================] - 5s 279ms/step - loss: 1.4705 - acc: 0.7311 - val_loss: 2.5302 - val_acc: 0.5601
# Epoch 25/50
# 14/14 [==============================] - 5s 279ms/step - loss: 1.1286 - acc: 0.7953 - val_loss: 2.3439 - val_acc: 0.6202
# Epoch 26/50
# 14/14 [==============================] - 5s 278ms/step - loss: 0.9990 - acc: 0.8266 - val_loss: 1.7604 - val_acc: 0.6827
# Epoch 27/50
# 14/14 [==============================] - 5s 279ms/step - loss: 1.1424 - acc: 0.7908 - val_loss: 1.5626 - val_acc: 0.6899
# Epoch 28/50
# 14/14 [==============================] - 5s 277ms/step - loss: 0.8109 - acc: 0.8574 - val_loss: 2.0685 - val_acc: 0.6538
# Epoch 29/50
# 14/14 [==============================] - 5s 269ms/step - loss: 0.9093 - acc: 0.8357 - val_loss: 1.5994 - val_acc: 0.7043
# Epoch 30/50
# 14/14 [==============================] - 5s 278ms/step - loss: 0.8479 - acc: 0.8435 - val_loss: 1.7689 - val_acc: 0.6803
# Epoch 31/50
# 14/14 [==============================] - 5s 282ms/step - loss: 0.8912 - acc: 0.8187 - val_loss: 1.4878 - val_acc: 0.6899
# Epoch 32/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.7575 - acc: 0.8649 - val_loss: 1.8250 - val_acc: 0.6707
# Epoch 33/50
# 14/14 [==============================] - 5s 278ms/step - loss: 0.8821 - acc: 0.8483 - val_loss: 1.7196 - val_acc: 0.6755
# Epoch 34/50
# 14/14 [==============================] - 5s 279ms/step - loss: 0.7549 - acc: 0.8632 - val_loss: 1.9078 - val_acc: 0.6418
# Epoch 35/50
# 14/14 [==============================] - 5s 271ms/step - loss: 0.7425 - acc: 0.8605 - val_loss: 1.8192 - val_acc: 0.6635
# Epoch 36/50
# 14/14 [==============================] - 5s 274ms/step - loss: 0.8829 - acc: 0.8363 - val_loss: 1.5313 - val_acc: 0.6899
# Epoch 37/50
# 14/14 [==============================] - 5s 279ms/step - loss: 0.6434 - acc: 0.8794 - val_loss: 1.7178 - val_acc: 0.6538
# Epoch 38/50
# 14/14 [==============================] - 5s 281ms/step - loss: 0.6641 - acc: 0.8937 - val_loss: 1.5349 - val_acc: 0.6755
# Epoch 39/50
# 14/14 [==============================] - 5s 283ms/step - loss: 0.6258 - acc: 0.8896 - val_loss: 1.2994 - val_acc: 0.7428
# Epoch 40/50
# 14/14 [==============================] - 5s 288ms/step - loss: 0.5672 - acc: 0.9094 - val_loss: 1.9013 - val_acc: 0.6562
# Epoch 41/50
# 14/14 [==============================] - 5s 279ms/step - loss: 0.6523 - acc: 0.8789 - val_loss: 2.2495 - val_acc: 0.6442
# Epoch 42/50
# 14/14 [==============================] - 5s 284ms/step - loss: 0.8042 - acc: 0.8693 - val_loss: 2.1160 - val_acc: 0.6514
# Epoch 43/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.7383 - acc: 0.8661 - val_loss: 1.9365 - val_acc: 0.6827
# Epoch 44/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.6224 - acc: 0.8824 - val_loss: 1.6181 - val_acc: 0.7067
# Epoch 45/50
# 14/14 [==============================] - 5s 283ms/step - loss: 0.5379 - acc: 0.9092 - val_loss: 1.5689 - val_acc: 0.6875
# Epoch 46/50
# 14/14 [==============================] - 5s 276ms/step - loss: 0.5374 - acc: 0.8983 - val_loss: 2.1475 - val_acc: 0.6418
# Epoch 47/50
# 14/14 [==============================] - 5s 283ms/step - loss: 0.7902 - acc: 0.8468 - val_loss: 1.4511 - val_acc: 0.7188
# Epoch 48/50
# 14/14 [==============================] - 5s 275ms/step - loss: 0.5628 - acc: 0.9057 - val_loss: 1.8852 - val_acc: 0.6899
# Epoch 49/50
# 14/14 [==============================] - 5s 282ms/step - loss: 0.6188 - acc: 0.8941 - val_loss: 1.8725 - val_acc: 0.6755
# Epoch 50/50
# 14/14 [==============================] - 5s 286ms/step - loss: 0.6197 - acc: 0.8847 - val_loss: 1.3069 - val_acc: 0.7308

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()

# %%
# Evaluating model on validation data
evaluate = model.evaluate(val_ds)
print(evaluate)
# Out:
# 4/4 [==============================] - 1s 138ms/step - loss: 1.3069 - acc: 0.7308
# [1.3068708181381226, 0.7307692170143127]

# %%
from sklearn.metrics import confusion_matrix


y_pred = model.predict(val_ds)
y_pred = np.argmax(y_pred,axis=1)
y_true = tf.concat([y for x, y in val_ds], axis=0)
con_mat = confusion_matrix(y_true, y_pred)

# %%
figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# The model didn't reach the expected 80% on the validation dataset and this might occur due to overfitting, we can see that the model reaches a 90+% training accuracy. Overfitting was improved from the base model by adding more hidden layers, dropout layers and adding augmentation to the data. The data could also be increased in size as it is too small for 21 different classes to train on such small dataset.
#
# From the confusion matrix we can see that classes 0, 11, 12, 16, 17 and 20 are misclassified the most on the validation set but it can also be seen that the validation dataset represents a very small poriton of the whole dataset specially that there is a lot of different classes to be classified.
#
# A better model would train on more datasets as transfer learning is used and with trial and error ResNet50 was chosen to be the best pre-trained model to be used.
